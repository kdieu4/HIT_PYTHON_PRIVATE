# %% [markdown]
# # 100 Bài Tập Xử Lý Dữ Liệu Có Cấu Trúc Với Pandas

# %% [markdown]
# ## Cài đặt và tải dữ liệu

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_rows = 100
pd.options.display.max_columns = 50

dtype = {
    'customer_id': str,
    'gender_cd': str,
    'postal_cd': str,
    'application_store_cd': str,
    'status_cd': str,
    'category_major_cd': str,
    'category_medium_cd': str,
    'category_small_cd': str,
    'product_cd': str,
    'store_cd': str,
    'prefecture_cd': str,
    'tel_no': str,
    'postal_cd': str,
    'street': str
}

df_customer = pd.read_csv("../../data/preprocessed/customer_eng.csv", dtype=dtype)
df_category = pd.read_csv("../../data/preprocessed/category_eng.csv", dtype=dtype)
df_product = pd.read_csv("../../data/preprocessed/product.csv", dtype=dtype)
df_receipt = pd.read_csv("../../data/preprocessed/receipt.csv", dtype=dtype)
df_store = pd.read_csv("../../data/preprocessed/store_eng.csv", dtype=dtype)
df_geocode = pd.read_csv("../../data/preprocessed/geocode_eng.csv", dtype=dtype)

# %% [markdown]
# ## Bài Tập

# %% [markdown]
# ### Phần 1: 1 - 20

# %% [markdown]
# ---
# > P-001: Từ dữ liệu biên nhận (df_receipt), hiển thị 10 bản ghi đầu tiên và kiểm tra xem loại dữ liệu nào được lưu trữ trong các cột.

# %%
df_receipt.head(10)
# Out:
#    sales_ymd  sales_epoch store_cd  receipt_no  receipt_sub_no  \
# 0   20181103   1541203200   S14006         112               1
# 1   20181118   1542499200   S13008        1132               2
# 2   20170712   1499817600   S14028        1102               1
# 3   20190205   1549324800   S14042        1132               1
# 4   20180821   1534809600   S14025        1102               2
# 5   20190605   1559692800   S13003        1112               1
# 6   20181205   1543968000   S14024        1102               2
# 7   20190922   1569110400   S14040        1102               1
# 8   20170504   1493856000   S13020        1112               2
# 9   20191010   1570665600   S14027        1102               1
#
#       customer_id  product_cd  quantity  amount
# 0  CS006214000001  P070305012         1     158
# 1  CS008415000097  P070701017         1      81
# 2  CS028414000014  P060101005         1     170
# 3  ZZ000000000000  P050301001         1      25
# 4  CS025415000050  P060102007         1      90
# 5  CS003515000195  P050102002         1     138
# 6  CS024514000042  P080101005         1      30
# 7  CS040415000178  P070501004         1     128
# 8  ZZ000000000000  P071302010         1     770
# 9  CS027514000015  P071101003         1     680

# %% [markdown]
# ---
# > P-002:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và hiển thị 10 bản ghi: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số tiền bán hàng (amount).

# %%
df_receipt.head(10)[['sales_ymd', 'customer_id', 'product_cd', 'amount']]
# Out:
#    sales_ymd     customer_id  product_cd  amount
# 0   20181103  CS006214000001  P070305012     158
# 1   20181118  CS008415000097  P070701017      81
# 2   20170712  CS028414000014  P060101005     170
# 3   20190205  ZZ000000000000  P050301001      25
# 4   20180821  CS025415000050  P060102007      90
# 5   20190605  CS003515000195  P050102002     138
# 6   20181205  CS024514000042  P080101005      30
# 7   20190922  CS040415000178  P070501004     128
# 8   20170504  ZZ000000000000  P071302010     770
# 9   20191010  CS027514000015  P071101003     680

# %% [markdown]
# ---
# > P-003:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và hiển thị 10 bản ghi: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số tiền bán hàng (amount). Tuy nhiên, đổi tên cột sales_ymd thành sales_date trước khi hiển thị.

# %%
df_receipt.head()[['sales_ymd', 'customer_id', 'product_cd', 'amount']].rename(columns={'sales_ymd':'sales_date'})
# Out:
#    sales_date     customer_id  product_cd  amount
# 0    20181103  CS006214000001  P070305012     158
# 1    20181118  CS008415000097  P070701017      81
# 2    20170712  CS028414000014  P060101005     170
# 3    20190205  ZZ000000000000  P050301001      25
# 4    20180821  CS025415000050  P060102007      90

# %% [markdown]
# ---
# > P-004:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và trích xuất dữ liệu đáp ứng các điều kiện dưới đây: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số tiền bán hàng (amount).
# > - ID khách hàng (customer_id) là "CS018205000001"

# %%
df_receipt[df_receipt['customer_id'] == 'CS018205000001'][['sales_ymd', 'customer_id', 'product_cd', 'amount']]
# Out:
#        sales_ymd     customer_id  product_cd  amount
# 36      20180911  CS018205000001  P071401012    2200
# 9843    20180414  CS018205000001  P060104007     600
# 21110   20170614  CS018205000001  P050206001     990
# 27673   20170614  CS018205000001  P060702015     108
# 27840   20190216  CS018205000001  P071005024     102
# 28757   20180414  CS018205000001  P071101002     278
# 39256   20190226  CS018205000001  P070902035     168
# 58121   20190924  CS018205000001  P060805001     495
# 68117   20190226  CS018205000001  P071401020    2200
# 72254   20180911  CS018205000001  P071401005    1100
# 88508   20190216  CS018205000001  P040101002     218
# 91525   20190924  CS018205000001  P091503001     280

# %% [markdown]
# ---
# > P-005:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và trích xuất dữ liệu đáp ứng tất cả các điều kiện dưới đây: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số tiền bán hàng (amount).
# > - ID khách hàng (customer_id) là "CS018205000001"
# > - Số tiền bán hàng (amount) lớn hơn hoặc bằng 1000

# %%
df_receipt[(df_receipt['customer_id'] == 'CS018205000001') & (df_receipt['amount'] >= 1000)][['sales_ymd', 'customer_id', 'product_cd', 'amount']]
# Out:
#        sales_ymd     customer_id  product_cd  amount
# 36      20180911  CS018205000001  P071401012    2200
# 68117   20190226  CS018205000001  P071401020    2200
# 72254   20180911  CS018205000001  P071401005    1100

# %% [markdown]
# ---
# > P-006:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và trích xuất dữ liệu đáp ứng tất cả các điều kiện dưới đây: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số lượng bán hàng (quantity), số tiền bán hàng (amount).
# > - ID khách hàng (customer_id) là "CS018205000001"
# > - Số tiền bán hàng (amount) lớn hơn hoặc bằng 1000 hoặc số lượng bán hàng (quantity) lớn hơn hoặc bằng 5

# %%
df_receipt[(df_receipt['customer_id'] == 'CS018205000001') & ((df_receipt['amount'] >= 1000) | (df_receipt['quantity'] >= 5)) ][['sales_ymd', 'customer_id', 'product_cd', 'quantity', 'amount']]
# Out:
#        sales_ymd     customer_id  product_cd  quantity  amount
# 36      20180911  CS018205000001  P071401012         1    2200
# 9843    20180414  CS018205000001  P060104007         6     600
# 21110   20170614  CS018205000001  P050206001         5     990
# 68117   20190226  CS018205000001  P071401020         1    2200
# 72254   20180911  CS018205000001  P071401005         1    1100

# %% [markdown]
# ---
# > P-007:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và trích xuất dữ liệu đáp ứng tất cả các điều kiện dưới đây: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số tiền bán hàng (amount).
# > - ID khách hàng (customer_id) là "CS018205000001"
# > - Số tiền bán hàng (amount) lớn hơn hoặc bằng 1000 và nhỏ hơn hoặc bằng 2000

# %%
df_receipt[(df_receipt['customer_id'] == 'CS018205000001') & ((df_receipt['amount'] >= 1000) & (df_receipt['amount'] <= 2000))][['sales_ymd', 'customer_id', 'product_cd', 'amount']]
# Out:
#        sales_ymd     customer_id  product_cd  amount
# 72254   20180911  CS018205000001  P071401005    1100

# %% [markdown]
# ---
# > P-008:
# Từ dữ liệu biên nhận (df_receipt), chỉ định các cột theo thứ tự sau và trích xuất dữ liệu đáp ứng tất cả các điều kiện dưới đây: ngày bán hàng (sales_ymd), ID khách hàng (customer_id), mã sản phẩm (product_cd), số tiền bán hàng (amount).
# > - ID khách hàng (customer_id) là "CS018205000001"
# > - Mã sản phẩm (product_cd) không phải là "P071401019"

# %%
df_receipt[(df_receipt['customer_id'] == 'CS018205000001') & (df_receipt['product_cd'] != 'P071401019')][['sales_ymd', 'customer_id', 'product_cd', 'amount']]
# Out:
#        sales_ymd     customer_id  product_cd  amount
# 36      20180911  CS018205000001  P071401012    2200
# 9843    20180414  CS018205000001  P060104007     600
# 21110   20170614  CS018205000001  P050206001     990
# 27673   20170614  CS018205000001  P060702015     108
# 27840   20190216  CS018205000001  P071005024     102
# 28757   20180414  CS018205000001  P071101002     278
# 39256   20190226  CS018205000001  P070902035     168
# 58121   20190924  CS018205000001  P060805001     495
# 68117   20190226  CS018205000001  P071401020    2200
# 72254   20180911  CS018205000001  P071401005    1100
# 88508   20190216  CS018205000001  P040101002     218
# 91525   20190924  CS018205000001  P091503001     280

# %% [markdown]
# ---
# > P-009: Thay đổi điều kiện lọc dưới đây và thay thế từ khóa OR thành AND trong truy vấn xuất dữ liệu.
# >
# > `df_store.query('not(prefecture_cd == "13" | floor_area > 900)')`

# %%
df_store.query ('prefecture_cd != "13" & floor_area <= 900')
# Out:
#    store_cd              store_name prefecture_cd           prefecture  \
# 18   S14046        Kitayamada store            14  Kanagawa Prefecture
# 20   S14011  Hiyoshi Honmachi store            14  Kanagawa Prefecture
# 38   S12013         Narashino store            12     Chiba prefecture
#
#                                               address        tel_no  \
# 18  Kitamada 1-chome, Tsuzuki-ku, Yokohama-shi, Ka...  045-123-4049
# 20  4-chome Honcho, Kohoku-ku, Yokohama-shi, Kanagawa  045-123-4033
# 38  1-chome Shibaen, Narashino City, Chiba Prefecture  047-123-4002
#
#     longitude  latitude  floor_area
# 18   139.5916  35.56189       831.0
# 20   139.6316  35.54655       890.0
# 38   140.0220  35.66122       808.0

# %% [markdown]
# ---
# > P-010:
# Từ dữ liệu cửa hàng (df_store), trích xuất và hiển thị 10 bản ghi với mã cửa hàng (store_cd) bắt đầu bằng 'S14'.

# %%
df_store.query("store_cd.str.startswith('S14')").head(10)
# Out:
#    store_cd                store_name prefecture_cd           prefecture  \
# 2    S14010              Kikuna store            14  Kanagawa Prefecture
# 3    S14033               Akuwa store            14  Kanagawa Prefecture
# 4    S14036  Sagamihara Central Store            14  Kanagawa Prefecture
# 7    S14040           Nagatsuta store            14  Kanagawa Prefecture
# 9    S14050         Akuwa Nishi store            14  Kanagawa Prefecture
# 12   S14028      Futatsu Bridge store            14  Kanagawa Prefecture
# 16   S14012        Honmaki Wada store            14  Kanagawa Prefecture
# 18   S14046          Kitayamada store            14  Kanagawa Prefecture
# 19   S14022               Zushi store            14  Kanagawa Prefecture
# 20   S14011    Hiyoshi Honmachi store            14  Kanagawa Prefecture
#
#                                               address        tel_no  \
# 2   Kikuna 1-chome, Kohoku-ku, Yokohama-shi, Kanagawa  045-123-4032
# 3   Akuwa Nishi 1-chome, Seya-ku, Yokohama-shi, Ka...  045-123-4043
# 4   2-chome, Chuo, Sagamihara City, Kanagawa Prefe...  042-123-4045
# 7   Nagatsuda Minamidai 5-chome, Midori-ku, Yokoha...  045-123-4046
# 9   Akuwa Nishi 1-chome, Seya-ku, Yokohama-shi, Ka...  045-123-4053
# 12  Futatsuhashi-cho, Seya-ku, Yokohama-shi, Kanagawa  045-123-4042
# 16      Honmaki Wada, Naka-ku, Yokohama-shi, Kanagawa  045-123-4034
# 18  Kitamada 1-chome, Tsuzuki-ku, Yokohama-shi, Ka...  045-123-4049
# 19     Zushi 1-chome, Zushi City, Kanagawa Prefecture  046-123-4036
# 20  4-chome Honcho, Kohoku-ku, Yokohama-shi, Kanagawa  045-123-4033
#
#     longitude  latitude  floor_area
# 2    139.6326  35.50049      1732.0
# 3    139.4961  35.45918      1495.0
# 4    139.3716  35.57327      1679.0
# 7    139.4994  35.52398      1548.0
# 9    139.4961  35.45918      1830.0
# 12   139.4963  35.46304      1574.0
# 16   139.6582  35.42156      1341.0
# 18   139.5916  35.56189       831.0
# 19   139.5789  35.29642      1838.0
# 20   139.6316  35.54655       890.0

# %% [markdown]
# ---
# > P-011:
# Từ dữ liệu khách hàng (df_customer), trích xuất và hiển thị 10 bản ghi với mã ID khách hàng (customer_id) kết thúc bằng '1'.

# %%
df_customer.query("customer_id.str.endswith('1')").head(10)
# Out:
#        customer_id             customer_name gender_cd  gender   birth_day  \
# 4   CS033515000071                 Yuki Suwa         1    Male  1966-04-30
# 7   CS022515000271             Riho Nakagawa         1    Male  1966-08-27
# 10  CS015212000021              Fujimura 7th         1    Male  1997-03-20
# 17  CS007502000011              Koji Asakura         0  Female  1962-07-28
# 20  CS004415000861               Ryoko Omori         1    Male  1974-01-28
# 36  CS007702000011  History of Takeshi Nagai         0  Female  1941-04-22
# 37  CS029503000041           Nakahara Subaru         0  Female  1966-02-13
# 60  CS005713000021                Ruria Noda         1    Male  1943-10-03
# 76  CS004603000051            Taro Matsutani         0  Female  1952-12-11
# 77  CS003314000081         Takakura sandbags         1    Male  1984-06-27
#
#     age postal_cd                                      address  \
# 4    52  246-0031            Seya -ku, Yokohama -shi, Kanagawa
# 7    52  249-0005  Sakurayama, Zushi City, Kanagawa Prefecture
# 10   22  136-0071                     Kameido, Koto -ku, Tokyo
# 17   56  285-0854        Kamiza, Sakura City, Chiba Prefecture
# 20   45  165-0032                Saginomiya, Nakano -ku, Tokyo
# 36   77  285-0866       Usuidai, Sakura City, Chiba Prefecture
# 37   53  134-0084            Higashi Kasai, Edogawa -ku, Tokyo
# 60   75  167-0022               Suginami -ku, Tokyo Shimoigusa
# 76   66  165-0032                Saginomiya, Nakano -ku, Tokyo
# 77   34  201-0012                    Komae -shi, Tokyo Ikuwaki
#
#    application_store_cd  application_date     status_cd
# 4                S14033          20151129  D-20100930-D
# 7                S14022          20181010  0-00000000-0
# 10               S13015          20150812  0-00000000-0
# 17               S12007          20150328  0-00000000-0
# 20               S13004          20170525  0-00000000-0
# 36               S12007          20150609  0-00000000-0
# 37               S12029          20150222  0-00000000-0
# 60               S13005          20150317  0-00000000-0
# 76               S13004          20161014  0-00000000-0
# 77               S13003          20150324  6-20100917-7

# %% [markdown]
# ---
# > P-012:
# Từ dữ liệu cửa hàng (df_store), trích xuất và hiển thị 10 bản ghi với địa chỉ (address) có chứa từ 'Tokyo'.

# %%
df_store.query("address.str.contains('Tokyo')").head(10)
# Out:
#    store_cd            store_name prefecture_cd prefecture  \
# 1    S13002      Kokubunji Temple            13      Tokyo
# 5    S13051  Itabashi Ohara store            13      Tokyo
# 6    S13015   Southern sand store            13      Tokyo
# 8    S13044  Minami -Rokugo store            13      Tokyo
# 10   S13019        Komorone store            13      Tokyo
# 11   S13052          Morino store            13      Tokyo
# 13   S13031        Hatsudai store            13      Tokyo
# 14   S13038    Higashikasai store            13      Tokyo
# 15   S13001    Naka -Rokugo store            13      Tokyo
# 17   S13004        Sagimiya store            13      Tokyo
#
#                                    address        tel_no  longitude  latitude  \
# 1     Honda 2-chome, Kokubunji City, Tokyo  042-123-4008   139.4802  35.70566
# 5            Ohara-cho, Itabashi-ku, Tokyo  03-0123-4029   139.6980  35.76788
# 6          2-chome, Koto-ku, Tokyo 2-chome  03-0123-4014   139.8229  35.67066
# 8     Minami Rokugo 2-chome, Ota-ku, Tokyo  03-0123-4028   139.7207  35.54604
# 10    Komorine 1-chome, Itabashi-ku, Tokyo  03-0123-4018   139.6795  35.74468
# 11    Morino Sanchome, Machida City, Tokyo  042-123-4030   139.4383  35.55293
# 13     Hatsudai 2-chome, Shibuya-ku, Tokyo  03-0123-4020   139.6862  35.67616
# 14  Tokyo Kasai 9-chome, Edogawa-ku, Tokyo  03-0123-4024   139.8826  35.65366
# 15      2-chome, Nakarokugo, Ota-ku, Tokyo  03-1234-4007   139.7132  35.55135
# 17   Saginomiya Sanchome, Nakano-ku, Tokyo  03-0123-4010   139.6421  35.72348
#
#     floor_area
# 1       1735.0
# 5       1045.0
# 6       1337.0
# 8       1379.0
# 10      1004.0
# 11      1087.0
# 13       986.0
# 14      1184.0
# 15      1796.0
# 17       947.0

# %% [markdown]
# ---
# > P-013:
# Từ dữ liệu khách hàng (df_customer), trích xuất và hiển thị 10 bản ghi với mã trạng thái (status_cd) bắt đầu bằng chữ cái từ 'A' đến 'F'.

# %%
df_customer[["customer_id", "customer_name", "address", "status_cd"]].query("status_cd.str.contains(r'^[A-F]')").head(10)
# Out:
#         customer_id   customer_name  \
# 0    CS019415000154    Yuki Umemura
# 4    CS033515000071       Yuki Suwa
# 16   CS024415000146  Sachiko Hosaka
# 45   CS019415000084     Honzan Mami
# 53   CS019214000008     Reina Okuno
# 54   CS002515000256    Yoko Kikuchi
# 63   CS017315000023    Reina Uchino
# 70   CS030415000034    Tamaki Nanko
# 72   CS025214000016  Furukawa Erika
# 101  CS021115000004   Hikaru Kurata
#
#                                                address     status_cd
# 0                         Hikawadai, Nerima -ku, Tokyo  E-20101014-E
# 4                    Seya -ku, Yokohama -shi, Kanagawa  D-20100930-D
# 16   Ikuta, Tama -ku, Kawasaki City, Kanagawa Prefe...  D-20101026-F
# 45                           Hazawa, Nerima -ku, Tokyo  C-20101012-E
# 53                         Chihaya, Toshima -ku, Tokyo  D-20100714-A
# 54                Kokubunji -shi, Tokyo Nishiki Kokubo  A-20100303-7
# 63                 Narita Higashi, Suginami -ku, Tokyo  C-20090424-5
# 70              Owada, Ichikawa City, Chiba Prefecture  F-20101020-F
# 72   Kamiiida -cho, Izumi -ku, Yokohama -shi, Kanagawa  D-20101029-F
# 101  Nishi -Tomioka, Isehara City, Kanagawa Prefecture  E-20100925-E

# %% [markdown]
# ---
# > P-014:
# Từ dữ liệu khách hàng (df_customer), trích xuất và hiển thị 10 bản ghi với mã trạng thái (status_cd) kết thúc bằng các số từ '1' đến '9'.

# %%
df_customer[["customer_id", "customer_name", "address", "status_cd"]].query("status_cd.str.contains(r'[1-9]$')").head(10)
# Out:
#        customer_id           customer_name  \
# 1   CS008514000047         Nozomi Ishikawa
# 3   CS004615000296             Yu Tateishi
# 8   CS020412000046  An apricot of Kurosaki
# 11  CS031514000047         Reiko Haraguchi
# 12  CS017513000183           Kyoko Suenaga
# 15  CS044415000024          Chikako Sugino
# 24  CS025512000055        Mayuko Mizuguchi
# 34  CS011315000042             Aya Inagaki
# 41  CS001315000186           Mikako Tomita
# 49  CS026615000130           Rie Matsunaga
#
#                                               address     status_cd
# 1                       Iwato Kita, Komae City, Tokyo  6-20100613-8
# 3                              Nakano -ku, Tokyo Nomo  4-20080701-1
# 8                        Shimura, Itabashi -ku, Tokyo  1-20100516-3
# 11                         Uehara, Shibuya -ku, Tokyo  8-20090607-6
# 12                             Nakano -ku, Tokyo Nomo  1-20090203-3
# 15                             Kamata, Ota -ku, Tokyo  6-20101016-9
# 24           Fukuda, Yamato City, Kanagawa Prefecture  4-20090705-4
# 34       Hiyoshi, Kohoku -ku, Yokohama -shi, Kanagawa  1-20080219-3
# 41                         Nakarokugo, Ota -ku, Tokyo  3-20080412-1
# 49  Tsujido Motomachi, Fujisawa City, Kanagawa Pre...  8-20090727-5

# %% [markdown]
# ---
# > P-015:
# Từ dữ liệu khách hàng (df_customer), trích xuất và hiển thị 10 bản ghi với mã trạng thái (status_cd) bắt đầu bằng chữ cái từ 'A' đến 'F' và kết thúc bằng các số từ '1' đến '9'.

# %%
df_customer[["customer_id", "customer_name", "address", "status_cd"]].query("status_cd.str.contains(r'^[A-F].*[1-9]$')").head(10)
# Out:
#         customer_id      customer_name  \
# 54   CS002515000256       Yoko Kikuchi
# 63   CS017315000023       Reina Uchino
# 163  CS022415000100    Misako Sunagawa
# 167  CS038314000035      Kyoko Okunuki
# 239  CS025512000143    Yoshino Kikuchi
# 282  CS010513000187    Asami Matsukawa
# 319  CS020212000014   Matsui Natsuzora
# 432  CS019215000029        Mayuko Sawa
# 520  CS015414000138       Erika Kusano
# 524  CS035615000040  Daigoro Kawanishi
#
#                                               address     status_cd
# 54               Kokubunji -shi, Tokyo Nishiki Kokubo  A-20100303-7
# 63                Narita Higashi, Suginami -ku, Tokyo  C-20090424-5
# 163         Shinjuku, Zushi City, Kanagawa Prefecture  B-20091009-9
# 167                 Higashi Kasai, Edogawa -ku, Tokyo  A-20100917-9
# 239         Shibuya, Yamato City, Kanagawa Prefecture  B-20090802-5
# 282  Samido -cho, Kohoku -ku, Yokohama -shi, Kanagawa  D-20100808-2
# 319     Kawaguchi, Kawaguchi City, Saitama Prefecture  E-20100524-7
# 432                      Sakuradai, Nerima -ku, Tokyo  A-20100622-9
# 520                    Minami sand in Koto -ku, Tokyo  D-20100504-9
# 524                   Kamimariga, Setagaya -ku, Tokyo  E-20100830-6

# %% [markdown]
# ---
# > P-016:
# Từ dữ liệu cửa hàng (df_store), trích xuất và hiển thị 10 bản ghi với số điện thoại (tel_no) tuân theo qui tắc xxx-xxx-xxxx. Trong đó x là 1 số tự nhiên từ 0-9.

# %%
df_store.query("tel_no.str.contains(r'^[0-9]{3}-[0-9]{3}-[0-9]{4}$')").head(10)
# Out:
#    store_cd                store_name prefecture_cd           prefecture  \
# 0    S12014          Chigakadai store            12     Chiba prefecture
# 1    S13002          Kokubunji Temple            13                Tokyo
# 2    S14010              Kikuna store            14  Kanagawa Prefecture
# 3    S14033               Akuwa store            14  Kanagawa Prefecture
# 4    S14036  Sagamihara Central Store            14  Kanagawa Prefecture
# 7    S14040           Nagatsuta store            14  Kanagawa Prefecture
# 9    S14050         Akuwa Nishi store            14  Kanagawa Prefecture
# 11   S13052              Morino store            13                Tokyo
# 12   S14028      Futatsu Bridge store            14  Kanagawa Prefecture
# 16   S14012        Honmaki Wada store            14  Kanagawa Prefecture
#
#                                               address        tel_no  \
# 0     1-chome, Chigusadai, Inage-ku, Chiba-shi, Chiba  043-123-4003
# 1                Honda 2-chome, Kokubunji City, Tokyo  042-123-4008
# 2   Kikuna 1-chome, Kohoku-ku, Yokohama-shi, Kanagawa  045-123-4032
# 3   Akuwa Nishi 1-chome, Seya-ku, Yokohama-shi, Ka...  045-123-4043
# 4   2-chome, Chuo, Sagamihara City, Kanagawa Prefe...  042-123-4045
# 7   Nagatsuda Minamidai 5-chome, Midori-ku, Yokoha...  045-123-4046
# 9   Akuwa Nishi 1-chome, Seya-ku, Yokohama-shi, Ka...  045-123-4053
# 11               Morino Sanchome, Machida City, Tokyo  042-123-4030
# 12  Futatsuhashi-cho, Seya-ku, Yokohama-shi, Kanagawa  045-123-4042
# 16      Honmaki Wada, Naka-ku, Yokohama-shi, Kanagawa  045-123-4034
#
#     longitude  latitude  floor_area
# 0    140.1180  35.63559      1698.0
# 1    139.4802  35.70566      1735.0
# 2    139.6326  35.50049      1732.0
# 3    139.4961  35.45918      1495.0
# 4    139.3716  35.57327      1679.0
# 7    139.4994  35.52398      1548.0
# 9    139.4961  35.45918      1830.0
# 11   139.4383  35.55293      1087.0
# 12   139.4963  35.46304      1574.0
# 16   139.6582  35.42156      1341.0

# %% [markdown]
# ---
# > P-017:
# Từ dữ liệu khách hàng (df_customer), sắp xếp và hiển thị 10 bản ghi đầu tiên theo thứ tự tăng dần của ngày sinh (birth_day).

# %%
df_customer.sort_values('birth_day').head(10)
# Out:
#         customer_id    customer_name gender_cd  gender   birth_day  age  \
# 401  CS017811000003     Yuu Kageyama         1    Male  1930-02-27   89
# 258  CS030802000009     Shingo Shogo         0  Female  1930-08-31   88
# 927  CS038813000006   Miyuki Toshima         1    Male  1931-01-07   88
# 640  CS005812000025       Ryo Nagase         1    Male  1931-10-06   87
# 200  CS024815000023  Mayuko Takenaka         1    Male  1931-11-25   87
# 812  CS034813000001      Yuko Yasuko         1    Male  1932-03-03   87
# 133  CS039813000020    Toshima light         1    Male  1932-03-29   87
# 129  CS002815000035       Ema Kawano         1    Male  1932-04-17   86
# 399  CS032815000020      Natsuki Doi         1    Male  1932-06-14   86
# 128  CS007813000023   Airi Mizoguchi         1    Male  1932-06-28   86
#
#     postal_cd                                            address  \
# 401  166-0001                    Asaya Kita, Suginami -ku, Tokyo
# 258  272-0803                               Ichikawa -shi, Chiba
# 927  134-0084                  Higashi Kasai, Edogawa -ku, Tokyo
# 640  176-0022                        Mukoyama, Nerima -ku, Tokyo
# 200  214-0035  Nagasawa, Tama -ku, Kawasaki City, Kanagawa Pr...
# 812  216-0001  Nogawa, Miyamae -ku, Kawasaki City, Kanagawa P...
# 133  167-0034                         Momoi, Suginami -ku, Tokyo
# 129  185-0024                       Izumi -cho, Kokubunji, Tokyo
# 399  144-0056                      Nishi -Rokugo, Ota -ku, Tokyo
# 128  285-0843           Nakashizu, Sakura City, Chiba Prefecture
#
#     application_store_cd  application_date     status_cd
# 401               S13017          20150224  0-00000000-0
# 258               S12030          20180506  0-00000000-0
# 927               S13038          20150603  0-00000000-0
# 640               S13005          20170524  0-00000000-0
# 200               S14024          20151030  2-20080925-4
# 812               S14034          20150625  0-00000000-0
# 133               S13039          20150630  0-00000000-0
# 129               S13002          20161227  3-20090908-2
# 399               S13032          20151104  0-00000000-0
# 128               S12007          20150501  0-00000000-0

# %% [markdown]
# ---
# > P-018:
# Từ dữ liệu khách hàng (df_customer), sắp xếp và hiển thị 10 bản ghi đầu tiên theo thứ tự giảm dần của ngày sinh (birth_day).

# %%
df_customer.sort_values('birth_day', ascending=False).head(10)
# Out:
#         customer_id         customer_name gender_cd   gender   birth_day  age  \
# 134  CS004112000011           Miyu Tamaki         1     Male  2007-01-03   12
# 516  CS021102000003              Nakahara         0   Female  2006-05-17   12
# 560  CS032115000007        Tomono Noguchi         1     Male  2006-04-11   12
# 44   CS019114000002            Mami Morii         1     Male  2004-12-17   14
# 703  CS037112000007         Sayaka Temple         1     Male  2004-01-20   15
# 250  CS032115000006  Koizumi High History         9  Unknown  2003-11-14   15
# 101  CS021115000004         Hikaru Kurata         1     Male  2003-01-19   16
# 512  CS030112000001       Haruki Yamauchi         1     Male  2002-01-26   17
# 867  CS011412000021           Riho Tamada         1     Male  1999-10-21   19
# 938  CS028213000058      Mayuko Terashima         1     Male  1997-12-17   21
#
#     postal_cd                                            address  \
# 134  161-0031                     Nishimoho, Shinjuku -ku, Tokyo
# 516  254-0004      Kobujima, Hiratsuka City, Kanagawa Prefecture
# 560  144-0056                      Nishi -Rokugo, Ota -ku, Tokyo
# 44   171-0041                        Chikawa, Toshima -ku, Tokyo
# 703  101-0031                  Higashi Kanda, Chiyoda -ku, Tokyo
# 250  144-0056                      Nishi -Rokugo, Ota -ku, Tokyo
# 101  259-1111  Nishi -Tomioka, Isehara City, Kanagawa Prefecture
# 512  272-0814       Takaishijin, Ichikawa City, Chiba Prefecture
# 867  165-0022                           Ekoda, Nakano -ku, Tokyo
# 938  246-0025      Akuwanishi, Seya -ku, Yokohama -shi, Kanagawa
#
#     application_store_cd  application_date     status_cd
# 134               S13004          20160615  0-00000000-0
# 516               S14021          20180510  0-00000000-0
# 560               S13032          20150428  B-20100822-A
# 44                S13019          20150507  0-00000000-0
# 703               S13037          20151108  0-00000000-0
# 250               S13032          20150223  6-20100725-A
# 101               S14021          20150212  E-20100925-E
# 512               S12030          20150620  0-00000000-0
# 867               S14011          20150526  4-20090412-3
# 938               S14028          20180806  0-00000000-0

# %% [markdown]
# ---
# > P-019:
# Từ dữ liệu biên nhận (df_receipt), xếp hạng số tiền bán hàng (amount) theo thứ tự giảm dần và hiển thị 10 bản ghi đầu tiên. Đính kèm các cột ID khách hàng (customer_id) và số tiền bán hàng (amount) với hạng tương ứng. Nếu số tiền bán hàng (amount) bằng nhau, hạng sẽ giống nhau.

# %%
df_tmp = df_receipt[["amount"]].rank(method="min", ascending=False).rename(columns={"amount":"ranking"}).astype("int")
df_tmp = pd.concat([df_receipt[["customer_id", "amount"]], df_tmp], axis=1)
df_tmp.sort_values("ranking").head(10)
# Out:
#           customer_id  amount  ranking
# 1202   CS011415000006   10925        1
# 62317  ZZ000000000000    6800        2
# 54095  CS028605000002    5780        3
# 72747  ZZ000000000000    5480        4
# 10320  ZZ000000000000    5480        4
# 4632   CS015515000034    5480        4
# 97294  CS021515000089    5440        7
# 28304  ZZ000000000000    5440        7
# 11275  CS017414000114    5280        9
# 55795  CS032414000072    5280        9

# %% [markdown]
# ---
# > P-020:
# Từ dữ liệu biên nhận (df_receipt), xếp hạng số tiền bán hàng (amount) theo thứ tự tăng dần và hiển thị 10 bản ghi đầu tiên. Đính kèm các cột ID khách hàng (customer_id) và số tiền bán hàng (amount) với hạng tương ứng. Trong trường hợp số tiền bán hàng (amount) bằng nhau hạng sẽ không được |giống nhau.

# %%
df_tmp = df_receipt[["amount"]].rank(method="first", ascending=False).rename(columns={"amount":"ranking"}).astype("int")
df_tmp = pd.concat([df_receipt[["customer_id", "amount"]], df_tmp], axis=1)
df_tmp.sort_values("ranking").head(10)
# Out:
#           customer_id  amount  ranking
# 1202   CS011415000006   10925        1
# 62317  ZZ000000000000    6800        2
# 54095  CS028605000002    5780        3
# 4632   CS015515000034    5480        4
# 10320  ZZ000000000000    5480        5
# 72747  ZZ000000000000    5480        6
# 28304  ZZ000000000000    5440        7
# 97294  CS021515000089    5440        8
# 596    CS015515000083    5280        9
# 11275  CS017414000114    5280       10

# %% [markdown]
# ### Phần 2: 21 - 40

# %% [markdown]
# ---
# > P-021:
# Từ dữ liệu biên nhận (df_receipt), đếm số lượng bản ghi.

# %%
len(df_receipt)
# Out:
# 104681

# %% [markdown]
# ---
# > P-022:
# Từ dữ liệu biên nhận (df_receipt), đếm số lượng các giá trị duy nhất của ID khách hàng (customer_id).

# %%
len(df_receipt["customer_id"].unique())
# Out:
# 8307

# %% [markdown]
# ---
# > P-023:
# Từ dữ liệu biên nhận (df_receipt), tính tổng số tiền bán hàng (amount) và số lượng bán hàng (quantity) cho mỗi cửa hàng (store_cd).

# %%
(df_receipt.groupby("store_cd")
    .agg (
        {
            "amount": "sum",
            "quantity": "sum"
        }
    ).reset_index()
).head(10)
# Out:
#   store_cd  amount  quantity
# 0   S12007  638761      2099
# 1   S12013  787513      2425
# 2   S12014  725167      2358
# 3   S12029  794741      2555
# 4   S12030  684402      2403
# 5   S13001  811936      2347
# 6   S13002  727821      2340
# 7   S13003  764294      2197
# 8   S13004  779373      2390
# 9   S13005  629876      2004

# %% [markdown]
# ---
# > P-024:
# Từ dữ liệu biên nhận (df_receipt), hiển thị 10 bản ghi có ngày bán hàng (sales_ymd) mới nhất cho mỗi ID khách hàng (customer_id).

# %%
(
    df_receipt.groupby("customer_id")
    .agg (
        {
            "sales_ymd": "max"
        }
    ).reset_index()
).head(10)
# Out:
#       customer_id  sales_ymd
# 0  CS001113000004   20190308
# 1  CS001114000005   20190731
# 2  CS001115000010   20190405
# 3  CS001205000004   20190625
# 4  CS001205000006   20190224
# 5  CS001211000025   20190322
# 6  CS001212000027   20170127
# 7  CS001212000031   20180906
# 8  CS001212000046   20170811
# 9  CS001212000070   20191018

# %% [markdown]
# ---
# > P-025:
# Từ dữ liệu biên nhận (df_receipt), hiển thị 10 bản ghi có ngày bán hàng (sales_ymd) cũ nhất cho mỗi ID khách hàng (customer_id).

# %%
(
    df_receipt.groupby("customer_id")
    .agg (
        {
            "sales_ymd": "min"
        }
    ).reset_index()
).head(10)
# Out:
#       customer_id  sales_ymd
# 0  CS001113000004   20190308
# 1  CS001114000005   20180503
# 2  CS001115000010   20171228
# 3  CS001205000004   20170914
# 4  CS001205000006   20180207
# 5  CS001211000025   20190322
# 6  CS001212000027   20170127
# 7  CS001212000031   20180906
# 8  CS001212000046   20170811
# 9  CS001212000070   20191018

# %% [markdown]
# ---
# > P-026:
# Từ dữ liệu biên nhận (df_receipt), hiển thị 10 bản ghi có ngày bán hàng (sales_ymd) mới nhất và cũ nhất cho mỗi ID khách hàng (customer_id). Nếu ngày bán hàng khác nhau, hiển thị 10 bản ghi.

# %%
df_tmp = df_receipt.groupby("customer_id").agg({'sales_ymd':['max', 'min']}).reset_index()
print(df_tmp.columns)
df_tmp.columns = ["_".join(pair) for pair in df_tmp.columns]
print(df_tmp.columns)
df_tmp.head(10)
df_tmp.query('sales_ymd_max != sales_ymd_min').head(10)
# Out:
# MultiIndex([('customer_id',    ''),
#             (  'sales_ymd', 'max'),
#             (  'sales_ymd', 'min')],
#            )
# Index(['customer_id_', 'sales_ymd_max', 'sales_ymd_min'], dtype='object')
#       customer_id_  sales_ymd_max  sales_ymd_min
# 1   CS001114000005       20190731       20180503
# 2   CS001115000010       20190405       20171228
# 3   CS001205000004       20190625       20170914
# 4   CS001205000006       20190224       20180207
# 13  CS001214000009       20190902       20170306
# 14  CS001214000017       20191006       20180828
# 16  CS001214000048       20190929       20171109
# 17  CS001214000052       20190617       20180208
# 20  CS001215000005       20181021       20170206
# 21  CS001215000040       20171022       20170214

# %% [markdown]
# ---
# > P-027:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị trung bình số tiền bán hàng (amount) theo cửa hàng (store_cd), sắp xếp và hiển thị TOP 5.

# %%
(
    df_receipt.groupby('store_cd')
    .agg ({'amount': 'mean'})
    .reset_index()
    .sort_values('amount', ascending=False)
).head(5)
# Out:
#    store_cd      amount
# 28   S13052  402.867470
# 12   S13015  351.111960
# 7    S13003  350.915519
# 30   S14010  348.791262
# 5    S13001  348.470386

# %% [markdown]
# ---
# > P-028:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị trung vị số tiền bán hàng (amount) theo cửa hàng (store_cd), sắp xếp và hiển thị TOP 5.

# %%
(
    df_receipt.groupby('store_cd')
    .agg({'amount':'median'})
    .reset_index()
    .sort_values('amount', ascending=False)
    .head(5)
)
# Out:
#    store_cd  amount
# 28   S13052   190.0
# 30   S14010   188.0
# 51   S14050   185.0
# 15   S13018   180.0
# 44   S14040   180.0

# %% [markdown]
# ---
# > P-029:
# Từ dữ liệu biên nhận (df_receipt), hiển thị 10 bản ghi có giá trị mode lớn nhất của mã sản phẩm (product_cd) theo cửa hàng (store_cd).

# %%
(
    df_receipt.groupby('store_cd')['product_cd']
    .apply(lambda x : x.mode())
    .reset_index()
).head(10)
# Out:
#   store_cd  level_1  product_cd
# 0   S12007        0  P060303001
# 1   S12013        0  P060303001
# 2   S12014        0  P060303001
# 3   S12029        0  P060303001
# 4   S12030        0  P060303001
# 5   S13001        0  P060303001
# 6   S13002        0  P060303001
# 7   S13003        0  P071401001
# 8   S13004        0  P060303001
# 9   S13005        0  P040503001

# %% [markdown]
# ---
# > P-030:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị phân vị của số tiền bán hàng (amount) theo cửa hàng (store_cd), sắp xếp và hiển thị TOP 5.

# %%
(
    df_receipt.groupby('store_cd').amount.var(ddof=0).reset_index()
    .sort_values('amount', ascending=False)
    .head(5)
)
# Out:
#    store_cd         amount
# 28   S13052  440088.701311
# 31   S14011  306314.558164
# 42   S14034  296920.081011
# 5    S13001  295431.993329
# 12   S13015  295294.361116

# %%
# Tham số ddof=0 có nghĩa là sử dụng mẫu đầy đủ (n) để tính phương sai, thay vì (n-1) mà là mặc định trong nhiều trường hợp tính phương sai mẫu

# %% [markdown]
# ---
# > P-031:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị độ lệch chuẩn của số tiền bán hàng (amount) theo cửa hàng (store_cd), sắp xếp và hiển thị TOP 5.

# %% [markdown]
# TIPS:
#
# Chú ý rằng mặc định `ddof` của Pandas và Numpy có thể khác nhau.
# ```
# Pandas：
# DataFrame.std(self, axis=None, skipna=None, level=None, ddof=1, numeric_only=None, **kwargs)
# Numpy:
# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=)
# ```

# %%
(
    df_receipt.groupby('store_cd').amount.std(ddof=0).reset_index()
    .sort_values('amount', ascending=False)
    .head(5)
)
# Out:
#    store_cd      amount
# 28   S13052  663.391816
# 31   S14011  553.456916
# 42   S14034  544.903736
# 5    S13001  543.536561
# 12   S13015  543.409938

# %% [markdown]
# ---
# > P-032:
# Từ dữ liệu biên nhận (df_receipt), tính phần trăm phân vị (percentile) của số tiền bán hàng (amount) cho các cột tương ứng với giá trị 25%.

# %%
# 1
np.percentile(df_receipt['amount'], q=np.arange(1, 5) * 25)
# Out:
# array([  102.,   170.,   288., 10925.])

# %%
# 2
df_receipt['amount'].quantile(q=[0.25, 0.5, 0.75, 1.0])
# Out:
# 0.25      102.0
# 0.50      170.0
# 0.75      288.0
# 1.00    10925.0
# Name: amount, dtype: float64

# %% [markdown]
# ---
# > P-033:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị số tiền bán hàng trung bình (amount) theo cửa hàng (store_cd), lọc ra các cửa hàng có trung bình lớn hơn hoặc bằng 330.

# %%
(
    df_receipt.groupby('store_cd').amount.mean()
    .reset_index()
    .query('amount > 330')
)
# Out:
#    store_cd      amount
# 1    S12013  330.194130
# 5    S13001  348.470386
# 7    S13003  350.915519
# 8    S13004  330.943949
# 12   S13015  351.111960
# 16   S13019  330.208616
# 17   S13020  337.879932
# 28   S13052  402.867470
# 30   S14010  348.791262
# 31   S14011  335.718333
# 38   S14026  332.340588
# 46   S14045  330.082073
# 48   S14047  330.077073

# %% [markdown]
# ---
# > P-034:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị số tiền bán hàng trung bình (amount) theo ID khách hàng (customer_id). Lưu ý loại bỏ các khách hàng có ID bắt đầu bằng 'Z' vì họ là nhân viên.

# %%
# 1 
print(
    df_receipt.query("~customer_id.str.startswith('Z')")
    .groupby("customer_id").amount.sum()
    .mean()
)
# Out:
# 2547.742234529256

# %%
# 2
print(
    df_receipt.query("not customer_id.str.startswith('Z')")
    .groupby("customer_id").amount.sum()
    .mean()
)
# Out:
# 2547.742234529256

# %%
# 3
print(
    df_receipt[~df_receipt["customer_id"].str.startswith('Z')]
    .groupby("customer_id").amount.sum()
    .mean()
)
# Out:
# 2547.742234529256

# %% [markdown]
# ---
# > P-035:
# Từ dữ liệu biên nhận (df_receipt), tính và hiển thị số tiền bán hàng trung bình (amount) theo ID khách hàng (customer_id). Lưu ý loại bỏ các khách hàng có ID bắt đầu bằng 'Z' vì họ là nhân viên và chỉ hiển thị những người có số lượng bán hàng trung bình lớn hơn giá trị trung bình.

# %%
df_amount_sum = (
    df_receipt[~df_receipt['customer_id'].str.startswith('Z')]
    .groupby('customer_id').amount.sum()
)

amount_mean = df_amount_sum.mean()

(
    df_amount_sum.reset_index()
    .query("amount >= @amount_mean")
    .head(10)
)
# Out:
#        customer_id  amount
# 2   CS001115000010    3044
# 4   CS001205000006    3337
# 13  CS001214000009    4685
# 14  CS001214000017    4132
# 17  CS001214000052    5639
# 21  CS001215000040    3496
# 30  CS001304000006    3726
# 32  CS001305000005    3485
# 33  CS001305000011    4370
# 53  CS001315000180    3300

# %% [markdown]
# ---
# > P-036:
# Kết hợp dữ liệu biên nhận (df_receipt) và dữ liệu cửa hàng (df_store), hiển thị 10 bản ghi đầu tiên bao gồm tất cả các cột từ dữ liệu biên nhận và tên cửa hàng (store_name) từ dữ liệu cửa hàng.

# %%
pd.merge (
    df_receipt, df_store[['store_cd','store_name']],
    how='inner', on='store_cd'
).head(10)
# Out:
#    sales_ymd  sales_epoch store_cd  receipt_no  receipt_sub_no  \
# 0   20181103   1541203200   S14006         112               1
# 1   20181118   1542499200   S13008        1132               2
# 2   20170712   1499817600   S14028        1102               1
# 3   20190205   1549324800   S14042        1132               1
# 4   20180821   1534809600   S14025        1102               2
# 5   20190605   1559692800   S13003        1112               1
# 6   20181205   1543968000   S14024        1102               2
# 7   20190922   1569110400   S14040        1102               1
# 8   20170504   1493856000   S13020        1112               2
# 9   20191010   1570665600   S14027        1102               1
#
#       customer_id  product_cd  quantity  amount              store_name
# 0  CS006214000001  P070305012         1     158          Kuzugaya store
# 1  CS008415000097  P070701017         1      81             Seijo store
# 2  CS028414000014  P060101005         1     170    Futatsu Bridge store
# 3  ZZ000000000000  P050301001         1      25    Niiyama Shinto store
# 4  CS025415000050  P060102007         1      90            Yamato store
# 5  CS003515000195  P050102002         1     138             Komae store
# 6  CS024514000042  P080101005         1      30              Mita store
# 7  CS040415000178  P070501004         1     128         Nagatsuta store
# 8  ZZ000000000000  P071302010         1     770     Jujo Nakahara store
# 9  CS027514000015  P071101003         1     680  Minami -Fujizawa store

# %% [markdown]
# ---
# > P-037:
# Kết hợp dữ liệu sản phẩm (df_product) và dữ liệu danh mục (df_category), hiển thị 10 bản ghi đầu tiên bao gồm tất cả các cột từ dữ liệu sản phẩm và tên danh mục (category_small_name) từ dữ liệu danh mục.

# %%
df_product.head()
# Out:
#    product_cd category_major_cd category_medium_cd category_small_cd  \
# 0  P040101001                04               0401            040101
# 1  P040101002                04               0401            040101
# 2  P040101003                04               0401            040101
# 3  P040101004                04               0401            040101
# 4  P040101005                04               0401            040101
#
#    unit_price  unit_cost
# 0       198.0      149.0
# 1       218.0      164.0
# 2       230.0      173.0
# 3       248.0      186.0
# 4       268.0      201.0

# %%
df_category.head()
# Out:
#   category_major_cd category_major_name category_medium_cd  \
# 0                 4           Side dish                401
# 1                 4           Side dish                401
# 2                 4           Side dish                402
# 3                 4           Side dish                402
# 4                 4           Side dish                402
#
#   category_medium_name category_small_cd  category_small_name
# 0                 Rice             40101                Lunch
# 1                 Rice             40102                Sushi
# 2            Tsukudani             40201    Seafood tsukudani
# 3            Tsukudani             40202  Sea grass tsukudani
# 4            Tsukudani             40203  Vegetable tsukudani

# %%
(
    df_category.assign(
        category_small_cd_new = df_category["category_small_cd"].apply(lambda x: x.zfill(6))
    )
).head()
# Out:
#   category_major_cd category_major_name category_medium_cd  \
# 0                 4           Side dish                401
# 1                 4           Side dish                401
# 2                 4           Side dish                402
# 3                 4           Side dish                402
# 4                 4           Side dish                402
#
#   category_medium_name category_small_cd  category_small_name  \
# 0                 Rice             40101                Lunch
# 1                 Rice             40102                Sushi
# 2            Tsukudani             40201    Seafood tsukudani
# 3            Tsukudani             40202  Sea grass tsukudani
# 4            Tsukudani             40203  Vegetable tsukudani
#
#   category_small_cd_new
# 0                040101
# 1                040102
# 2                040201
# 3                040202
# 4                040203

# %%
df_category = (
    df_category.assign(
        category_small_cd = df_category["category_small_cd"].apply(lambda x: x.zfill(6))
    )
)
df_category.head(10)

df_product.merge(
    df_category[['category_small_cd', 'category_small_name']],
    on='category_small_cd',
    how='inner'
).head(10)
# Out:
#    product_cd category_major_cd category_medium_cd category_small_cd  \
# 0  P040101001                04               0401            040101
# 1  P040101002                04               0401            040101
# 2  P040101003                04               0401            040101
# 3  P040101004                04               0401            040101
# 4  P040101005                04               0401            040101
# 5  P040101006                04               0401            040101
# 6  P040101007                04               0401            040101
# 7  P040101008                04               0401            040101
# 8  P040101009                04               0401            040101
# 9  P040101010                04               0401            040101
#
#    unit_price  unit_cost category_small_name
# 0       198.0      149.0               Lunch
# 1       218.0      164.0               Lunch
# 2       230.0      173.0               Lunch
# 3       248.0      186.0               Lunch
# 4       268.0      201.0               Lunch
# 5       298.0      224.0               Lunch
# 6       338.0      254.0               Lunch
# 7       420.0      315.0               Lunch
# 8       498.0      374.0               Lunch
# 9       580.0      435.0               Lunch

# %% [markdown]
# ---
# > P-038: Từ dữ liệu khách hàng (df_customer) và dữ liệu chi tiết hóa đơn (df_receipt), hãy tính tổng số tiền bán hàng cho mỗi khách hàng và hiển thị 10 mục. Tuy nhiên, đối với khách hàng không có thành tích bán hàng, hiển thị tổng số tiền bán hàng là 0. Ngoài ra, chỉ xem xét khách hàng có mã giới tính (gender_cd) là nữ (1), và loại trừ khách hàng không phải là thành viên (khách hàng có ID khách hàng bắt đầu bằng "Z").

# %%
df_amount_sum = (
    df_receipt.groupby('customer_id').amount.sum()
).reset_index()

df_tmp = (
    df_customer.query("gender_cd == '1' and not customer_id.str.startswith('Z')")
)
pd.merge (
    df_tmp['customer_id'], df_amount_sum,
    on='customer_id', how = 'left'
).fillna(0).head(10)

# df_amount_sum.head()
# Out:
#       customer_id  amount
# 0  CS008514000047   889.0
# 1  CS038615000025     0.0
# 2  CS004615000296   566.0
# 3  CS033515000071  4540.0
# 4  CS022515000271     0.0
# 5  CS020412000046   208.0
# 6  CS002515000759     0.0
# 7  CS015212000021     0.0
# 8  CS031514000047  1554.0
# 9  CS017513000183   140.0

# %% [markdown]
# ---
# > P-039: Từ dữ liệu chi tiết hóa đơn (df_receipt), hãy tạo dữ liệu của 20 khách hàng có số ngày bán hàng nhiều nhất và dữ liệu của 20 khách hàng có tổng số tiền bán hàng nhiều nhất, và sau outer join hai dữ liệu này. Tuy nhiên, loại trừ khách hàng không phải là thành viên (khách hàng có ID khách hàng bắt đầu bằng "Z").

# %%
df_receipt.head()
# Out:
#    sales_ymd  sales_epoch store_cd  receipt_no  receipt_sub_no  \
# 0   20181103   1541203200   S14006         112               1
# 1   20181118   1542499200   S13008        1132               2
# 2   20170712   1499817600   S14028        1102               1
# 3   20190205   1549324800   S14042        1132               1
# 4   20180821   1534809600   S14025        1102               2
#
#       customer_id  product_cd  quantity  amount
# 0  CS006214000001  P070305012         1     158
# 1  CS008415000097  P070701017         1      81
# 2  CS028414000014  P060101005         1     170
# 3  ZZ000000000000  P050301001         1      25
# 4  CS025415000050  P060102007         1      90

# %%
df_data = df_receipt[~ df_receipt["customer_id"].str.startswith('Z')]

df_count = (
    df_data[~df_data.duplicated(subset=['customer_id', 'sales_ymd'])]
    .groupby('customer_id').sales_ymd.count().reset_index()
    .rename(columns={'sales_ymd':'sale_days'})
    .sort_values('sale_days', ascending=False).head(20)
)

df_sum = (
    df_data.groupby('customer_id').amount.sum().reset_index()
    .sort_values('amount', ascending=False).head(20)
)

pd.merge(df_count, df_sum, how='outer', on='customer_id').fillna(0).head()
# Out:
#       customer_id  sale_days   amount
# 0  CS001605000009        0.0  18925.0
# 1  CS006515000023        0.0  18372.0
# 2  CS007514000094        0.0  15735.0
# 3  CS007515000107       18.0      0.0
# 4  CS009414000059        0.0  15492.0

# %% [markdown]
# ---
# > P-040: Tạo dữ liệu kết hợp tất cả các cửa hàng và tất cả các sản phẩm (cross join). Hãy nhân trực tiếp dữ liệu cửa hàng (df_store) và dữ liệu sản phẩm (df_product) và tính số lượng.

# %%
df_store_tmp = df_store.copy()
df_product_tmp = df_product.copy()

df_store_tmp['key'] = 1
df_product_tmp['key'] = 1

len (pd.merge(df_store_tmp, df_product_tmp, on="key", how="outer"))
# Out:
# 531590

# %% [markdown]
# ### Phần 3: 41 - 60

# %% [markdown]
# ---
# > P-041: Từ dữ liệu chi tiết hóa đơn (df_receipt), hãy tính tổng hợp số tiền bán hàng (amount) theo ngày (sales_ymd) và tính toán sự thay đổi của doanh thu so với ngày bán hàng trước đó. Sau đó, hiển thị kết quả 10 mục.

# %%
df_sales_amount_by_date = df_receipt[['sales_ymd', 'amount']].groupby('sales_ymd').sum().reset_index()
# df_sales_amount_by_date

# df_sales_amount_by_date.shift()

df_concated = pd.concat([df_sales_amount_by_date, df_sales_amount_by_date.shift()], axis=1)
df_concated.columns = ['sales_ymd', 'amount', 'lag_ymd', 'lag_amount']

df_concated['diff_amount'] = df_concated['amount'] - df_concated['lag_amount']
df_concated.head(10)
# Out:
#    sales_ymd  amount     lag_ymd  lag_amount  diff_amount
# 0   20170101   33723         NaN         NaN          NaN
# 1   20170102   24165  20170101.0     33723.0      -9558.0
# 2   20170103   27503  20170102.0     24165.0       3338.0
# 3   20170104   36165  20170103.0     27503.0       8662.0
# 4   20170105   37830  20170104.0     36165.0       1665.0
# 5   20170106   32387  20170105.0     37830.0      -5443.0
# 6   20170107   23415  20170106.0     32387.0      -8972.0
# 7   20170108   24737  20170107.0     23415.0       1322.0
# 8   20170109   26718  20170108.0     24737.0       1981.0
# 9   20170110   20143  20170109.0     26718.0      -6575.0

# %% [markdown]
# ---
# > P-042: Từ dữ liệu chi tiết hóa đơn (df_receipt), hãy tính tổng hợp số tiền bán hàng (amount) theo ngày (sales_ymd) và đối với dữ liệu của mỗi ngày, kết hợp với dữ liệu của ngày trước, hai ngày trước và ba ngày trước có doanh số. Sau đó, hiển thị 10 kết quả.

# %%
df_sales_amount_by_date = df_receipt[['sales_ymd', 'amount']].groupby('sales_ymd').sum().reset_index()

df_lag = df_sales_amount_by_date.copy()

for i in range(1, 4):
    df_tmp = (
        df_sales_amount_by_date.shift(i)
        .rename (
            columns={'sales_ymd': f'lag_ymd_{i}',
                    'amount': f'lag_amount_{i}'}
        )
    )
    df_lag = pd.concat([df_lag, df_tmp], axis=1)

df_lag.dropna().astype('int').head(10)
# Out:
#     sales_ymd  amount  lag_ymd_1  lag_amount_1  lag_ymd_2  lag_amount_2  \
# 3    20170104   36165   20170103         27503   20170102         24165
# 4    20170105   37830   20170104         36165   20170103         27503
# 5    20170106   32387   20170105         37830   20170104         36165
# 6    20170107   23415   20170106         32387   20170105         37830
# 7    20170108   24737   20170107         23415   20170106         32387
# 8    20170109   26718   20170108         24737   20170107         23415
# 9    20170110   20143   20170109         26718   20170108         24737
# 10   20170111   24287   20170110         20143   20170109         26718
# 11   20170112   23526   20170111         24287   20170110         20143
# 12   20170113   28004   20170112         23526   20170111         24287
#
#     lag_ymd_3  lag_amount_3
# 3    20170101         33723
# 4    20170102         24165
# 5    20170103         27503
# 6    20170104         36165
# 7    20170105         37830
# 8    20170106         32387
# 9    20170107         23415
# 10   20170108         24737
# 11   20170109         26718
# 12   20170110         20143

# %% [markdown]
# ''---
# > P-043: Kết hợp dữ liệu chi tiết hóa đơn (df_receipt) và dữ liệu khách hàng (df_customer), tạo dữ liệu tóm tắt bán hàng bằng cách tổng hợp số tiền bán hàng (amount) theo mã giới tính (gender_cd) và era (tính từ tuổi - age). Mã giới tính 0 là nam, 1 là nữ, 9 là không xác định.
# >
# > - Cấu trúc các mục bao gồm 4 hạng mục: era (chia thập kỷ theo mỗi 10 tuổi) và 3 cột bao gồm số tiền bán hàng của nữ giới, số tiền bán hàng của nam giới, số tiền bán hàng không xác định giới tính.

# %%
df_tmp = pd.merge(df_receipt, df_customer, on='customer_id', how='inner')

df_tmp["era"] = df_tmp["age"].apply(lambda x: math.floor(x/10) * 10)
df_tmp[['era', 'gender_cd', 'amount']].head(10)

df_sales_summary = pd.pivot_table(
    data=df_tmp[['era', 'gender_cd', 'amount']],
    index='era',
    columns='gender_cd',
    values='amount',
    aggfunc='sum'
).reset_index()

df_sales_summary.columns = ['era', 'male', 'female', 'unknown']
df_sales_summary
# Out:
#    era     male    female  unknown
# 0   10      NaN   10034.0    890.0
# 1   20   7382.0   79059.0   9059.0
# 2   30  25203.0   66923.0   3312.0
# 3   40      NaN  444352.0  19871.0
# 4   50    604.0  287987.0   4409.0
# 5   60   2638.0   48085.0   6664.0
# 6   70      NaN    1181.0      NaN
# 7   80   1104.0    1310.0      NaN

# %% [markdown]
# ---
# > P-044: Dữ liệu tóm tắt bán hàng (df_sales_summary) được tạo ra ở P-043 có chứa thông tin bán hàng theo giới tính. Từ dữ liệu này, chuyển đổi dữ liệu thành 3 hạng mục: thập kỷ - era, mã giới tính và số tiền bán hàng. Tuy nhiên, mã giới tính sẽ được chuyển đổi: nam là "00", nữ là "01", và không xác định là "99".

# %%
(
    df_sales_summary
    .set_index('era')
    .stack()
    .reset_index()
    .rename (columns={'level_1': 'gender_cd', 0:'amount'})
    .replace(
        {
            "female":"01",
            "male":"02",
            "unknown":"99",
        }
    )
)
# Out:
#     era gender_cd    amount
# 0    10        01   10034.0
# 1    10        99     890.0
# 2    20        02    7382.0
# 3    20        01   79059.0
# 4    20        99    9059.0
# 5    30        02   25203.0
# 6    30        01   66923.0
# 7    30        99    3312.0
# 8    40        01  444352.0
# 9    40        99   19871.0
# 10   50        02     604.0
# 11   50        01  287987.0
# 12   50        99    4409.0
# 13   60        02    2638.0
# 14   60        01   48085.0
# 15   60        99    6664.0
# 16   70        01    1181.0
# 17   80        02    1104.0
# 18   80        01    1310.0

# %% [markdown]
# ---
# > P-045:
# Chuyển đổi định dạng ngày sinh (birth_day) trong dữ liệu khách hàng (df_customer) sang chuỗi ký tự YYYYMMDD, hiển thị 10 bản ghi đầu tiên cùng với ID khách hàng (customer_id).

# %%
# df_customer
df_customer[['customer_id', 'birth_day']].head(10).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  10 non-null     object
#  1   birth_day    10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
(
    df_customer.assign(
        birth_day = lambda df: pd.to_datetime(df['birth_day']),
        new_birth_day = lambda df: pd.to_datetime(df['birth_day']).dt.strftime("%Y/%m/%d")
    )[['customer_id', 'birth_day', 'new_birth_day']]
).head(10)
# Out:
#       customer_id  birth_day new_birth_day
# 0  CS019415000154 1971-07-08    1971/07/08
# 1  CS008514000047 1962-04-03    1962/04/03
# 2  CS038615000025 1955-06-29    1955/06/29
# 3  CS004615000296 1950-02-23    1950/02/23
# 4  CS033515000071 1966-04-30    1966/04/30
# 5  CS041402000009 1973-10-30    1973/10/30
# 6  CS001603000084 1956-08-02    1956/08/02
# 7  CS022515000271 1966-08-27    1966/08/27
# 8  CS020412000046 1971-12-09    1971/12/09
# 9  CS002515000759 1963-07-15    1963/07/15

# %% [markdown]
# ---
# > P-046:
# Chuyển đổi định dạng ngày đăng ký (application_date) trong dữ liệu khách hàng (df_customer) sang chuỗi ký tự YYYYMMDD, hiển thị 10 bản ghi đầu tiên cùng với ID khách hàng (customer_id).

# %%
(
    df_customer.assign(
        application_date = lambda df: pd.to_datetime(df['application_date'], format="%Y%m%d")
    )[['customer_id','application_date']].head(10)
)
# Out:
#       customer_id application_date
# 0  CS019415000154       2015-05-06
# 1  CS008514000047       2015-04-23
# 2  CS038615000025       2014-12-22
# 3  CS004615000296       2016-06-18
# 4  CS033515000071       2015-11-29
# 5  CS041402000009       2018-05-01
# 6  CS001603000084       2017-09-19
# 7  CS022515000271       2018-10-10
# 8  CS020412000046       2015-08-20
# 9  CS002515000759       2017-12-13

# %% [markdown]
# ---
# > P-047:
# Chuyển đổi định dạng ngày bán hàng (sales_ymd) trong dữ liệu biên nhận (df_receipt) sang chuỗi ký tự YYYYMMDD, hiển thị 10 bản ghi đầu tiên cùng với số biên nhận (receipt_no) và số phụ của biên nhận (receipt_sub_no).

# %%
(
    df_receipt.assign(
        sales_ymd = lambda df: pd.to_datetime(df['sales_ymd'], format="%Y%m%d")
    )[['receipt_no', 'receipt_sub_no', 'sales_ymd']]
).head(10)
# Out:
#    receipt_no  receipt_sub_no  sales_ymd
# 0         112               1 2018-11-03
# 1        1132               2 2018-11-18
# 2        1102               1 2017-07-12
# 3        1132               1 2019-02-05
# 4        1102               2 2018-08-21
# 5        1112               1 2019-06-05
# 6        1102               2 2018-12-05
# 7        1102               1 2019-09-22
# 8        1112               2 2017-05-04
# 9        1102               1 2019-10-10

# %% [markdown]
# ---
# > P-048: Dữ liệu chi tiết hóa đơn (df_receipt) lưu trữ thời gian bán hàng dưới dạng giây Epoch (sales_epoch) với giá trị số dưới định dạng UNIX. Hãy chuyển đổi dữ liệu này sang định dạng ngày tháng, và hiển thị cùng với số hóa đơn (receipt_no) và số phụ hóa đơn (receipt_sub_no), tổng cộng 10 mục.

# %%
df_receipt.head(10).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_ymd       10 non-null     int64
#  1   sales_epoch     10 non-null     int64
#  2   store_cd        10 non-null     object
#  3   receipt_no      10 non-null     int64
#  4   receipt_sub_no  10 non-null     int64
#  5   customer_id     10 non-null     object
#  6   product_cd      10 non-null     object
#  7   quantity        10 non-null     int64
#  8   amount          10 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 852.0+ bytes

# %%
(
    df_receipt.assign(
        sales_ymd = lambda df: pd.to_datetime(df['sales_epoch'], unit='s')
    )[['receipt_no', 'receipt_sub_no', 'sales_ymd']]
).head(10)
# Out:
#    receipt_no  receipt_sub_no  sales_ymd
# 0         112               1 2018-11-03
# 1        1132               2 2018-11-18
# 2        1102               1 2017-07-12
# 3        1132               1 2019-02-05
# 4        1102               2 2018-08-21
# 5        1112               1 2019-06-05
# 6        1102               2 2018-12-05
# 7        1102               1 2019-09-22
# 8        1112               2 2017-05-04
# 9        1102               1 2019-10-10

# %% [markdown]
# ---
# > P-049: Chuyển đổi thời gian bán hàng dạng giây Epoch (sales_epoch) trong dữ liệu chi tiết hóa đơn (df_receipt) sang định dạng ngày tháng, chỉ lấy ra "năm", và hiển thị cùng với số hóa đơn (receipt_no) và số phụ hóa đơn (receipt_sub_no), tổng cộng 10 mục.

# %%
# 1
(
    df_receipt.assign(
        sales_year = lambda df: pd.to_datetime(df['sales_epoch'], unit='s').dt.year
    )[['receipt_no', 'receipt_sub_no', 'sales_year']]
).head(10)
# Out:
#    receipt_no  receipt_sub_no  sales_year
# 0         112               1        2018
# 1        1132               2        2018
# 2        1102               1        2017
# 3        1132               1        2019
# 4        1102               2        2018
# 5        1112               1        2019
# 6        1102               2        2018
# 7        1102               1        2019
# 8        1112               2        2017
# 9        1102               1        2019

# %%
# 2
pd.concat([df_receipt[['receipt_no', 'receipt_sub_no']],
        pd.to_datetime(df_receipt['sales_epoch'], unit='s').dt.year.rename('sales_year')],
        axis=1).head(10)
# Out:
#    receipt_no  receipt_sub_no  sales_year
# 0         112               1        2018
# 1        1132               2        2018
# 2        1102               1        2017
# 3        1132               1        2019
# 4        1102               2        2018
# 5        1112               1        2019
# 6        1102               2        2018
# 7        1102               1        2019
# 8        1112               2        2017
# 9        1102               1        2019

# %% [markdown]
# ---
# > P-050: Chuyển đổi thời gian bán hàng dạng giây Epoch (sales_epoch) trong dữ liệu chi tiết hóa đơn (df_receipt) sang định dạng ngày tháng, chỉ lấy ra "tháng" và hiển thị cùng với số hóa đơn (receipt_no) và số phụ hóa đơn (receipt_sub_no), tổng cộng 10 mục. Lưu ý, "tháng" được định dạng với hai chữ số, bổ sung số 0 nếu cần thiết.

# %%
# 1
(
    df_receipt.assign(
        sales_month = lambda df: pd.to_datetime(df['sales_epoch'], unit='s').dt.strftime('%m')
    )[['receipt_no', 'receipt_sub_no', 'sales_month']]
).head(10)
# Out:
#    receipt_no  receipt_sub_no sales_month
# 0         112               1          11
# 1        1132               2          11
# 2        1102               1          07
# 3        1132               1          02
# 4        1102               2          08
# 5        1112               1          06
# 6        1102               2          12
# 7        1102               1          09
# 8        1112               2          05
# 9        1102               1          10

# %%
# 2
pd.concat([df_receipt[['receipt_no', 'receipt_sub_no']],
        (pd.to_datetime(df_receipt['sales_epoch'], unit='s').dt.strftime('%m').rename('sales_month'))],
        axis=1).head(10)
# Out:
#    receipt_no  receipt_sub_no sales_month
# 0         112               1          11
# 1        1132               2          11
# 2        1102               1          07
# 3        1132               1          02
# 4        1102               2          08
# 5        1112               1          06
# 6        1102               2          12
# 7        1102               1          09
# 8        1112               2          05
# 9        1102               1          10

# %% [markdown]
# ---
# > P-051:
# Chuyển đổi ngày bán hàng (sales_ymd) trong dữ liệu biên nhận (df_receipt) sang định dạng ngày, chỉ lấy ra phần "ngày", hiển thị 10 bản ghi đầu tiên cùng với số biên nhận (receipt_no) và số phụ của biên nhận (receipt_sub_no). Lưu ý: chỉ lấy phần ngày, bỏ qua các phần khác trong ngày tháng.

# %%
# 1
(
    df_receipt.assign(
        sales_day = lambda df: pd.to_datetime(df['sales_epoch']).dt.strftime('%d')
    )[['receipt_no', 'receipt_sub_no', 'sales_day']]
).head(10)
# Out:
#    receipt_no  receipt_sub_no sales_day
# 0         112               1        01
# 1        1132               2        01
# 2        1102               1        01
# 3        1132               1        01
# 4        1102               2        01
# 5        1112               1        01
# 6        1102               2        01
# 7        1102               1        01
# 8        1112               2        01
# 9        1102               1        01

# %%
# 2
pd.concat([df_receipt[['receipt_no', 'receipt_sub_no']],
        pd.to_datetime(df_receipt['sales_ymd']).dt.strftime('%d').rename('sales_day')],
        axis=1).head(10)
# Out:
#    receipt_no  receipt_sub_no sales_day
# 0         112               1        01
# 1        1132               2        01
# 2        1102               1        01
# 3        1132               1        01
# 4        1102               2        01
# 5        1112               1        01
# 6        1102               2        01
# 7        1102               1        01
# 8        1112               2        01
# 9        1102               1        01

# %%
# Lấy ngày, tháng, năm chỉ trong 1 câu lệnh
(
    df_receipt.assign (
        sales_year = lambda df: pd.to_datetime(df['sales_epoch'], unit='s').dt.strftime("%Y"),
        sales_month = lambda df: pd.to_datetime(df['sales_epoch'], unit='s').dt.strftime("%Y"),
        sales_day = lambda df: pd.to_datetime(df['sales_epoch'], unit='s').dt.strftime("%Y")
    )[['receipt_no', 'receipt_sub_no', 'sales_year', 'sales_month', 'sales_day']]
).head(10)
# Out:
#    receipt_no  receipt_sub_no sales_year sales_month sales_day
# 0         112               1       2018        2018      2018
# 1        1132               2       2018        2018      2018
# 2        1102               1       2017        2017      2017
# 3        1132               1       2019        2019      2019
# 4        1102               2       2018        2018      2018
# 5        1112               1       2019        2019      2019
# 6        1102               2       2018        2018      2018
# 7        1102               1       2019        2019      2019
# 8        1112               2       2017        2017      2017
# 9        1102               1       2019        2019      2019

# %% [markdown]
# ---
# > P-052: Tổng hợp số tiền bán hàng (amount) trong dữ liệu chi tiết hóa đơn (df_receipt) theo từng khách hàng (customer_id). Nếu tổng số tiền lớn hơn 2000 hiển thị là 1 và nếu dưới 2000 hiển thị là 0. Hiển thị tổng cộng 10 mục. Tuy nhiên, loại trừ các khách hàng không phải là thành viên (có ID khách hàng bắt đầu bằng "Z").

# %%
# 1
(
    df_receipt[~df_receipt['customer_id'].str.startswith('Z')][['customer_id', 'amount']]
    .groupby('customer_id').amount.sum().reset_index()
    .assign(
        sales_flg = lambda df: df['amount'].apply(lambda x: 1 if x > 2000 else 0)
    )
    .head(10)
)
# Out:
#       customer_id  amount  sales_flg
# 0  CS001113000004    1298          0
# 1  CS001114000005     626          0
# 2  CS001115000010    3044          1
# 3  CS001205000004    1988          0
# 4  CS001205000006    3337          1
# 5  CS001211000025     456          0
# 6  CS001212000027     448          0
# 7  CS001212000031     296          0
# 8  CS001212000046     228          0
# 9  CS001212000070     456          0

# %%
# 2
df_sales_amount = df_receipt.query('not customer_id.str.startswith("Z")', engine='python')
df_sales_amount = df_sales_amount.groupby('customer_id').amount.sum().reset_index()
df_sales_amount['sales_flg'] = df_sales_amount['amount'].apply(lambda x: 1 if x > 2000 else 0)
df_sales_amount.head(10)
# Out:
#       customer_id  amount  sales_flg
# 0  CS001113000004    1298          0
# 1  CS001114000005     626          0
# 2  CS001115000010    3044          1
# 3  CS001205000004    1988          0
# 4  CS001205000006    3337          1
# 5  CS001211000025     456          0
# 6  CS001212000027     448          0
# 7  CS001212000031     296          0
# 8  CS001212000046     228          0
# 9  CS001212000070     456          0

# %%
# 3
df_sales_amount = df_receipt.query('not customer_id.str.startswith("Z")', engine='python')
df_sales_amount = df_sales_amount.groupby('customer_id').amount.sum().reset_index()
df_sales_amount['sales_flg'] = np.where(df_sales_amount['amount'] > 2000, 1, 0)
df_sales_amount.head(10)
# Out:
#       customer_id  amount  sales_flg
# 0  CS001113000004    1298          0
# 1  CS001114000005     626          0
# 2  CS001115000010    3044          1
# 3  CS001205000004    1988          0
# 4  CS001205000006    3337          1
# 5  CS001211000025     456          0
# 6  CS001212000027     448          0
# 7  CS001212000031     296          0
# 8  CS001212000046     228          0
# 9  CS001212000070     456          0

# %% [markdown]
# ---
# > P-053: Đối với mã bưu điện (postal_cd) trong dữ liệu khách hàng (df_customer), gán giá trị 1 cho các mã bưu điện thuộc Tokyo (có ba chữ số đầu tiên từ 100 đến 209) và giá trị 0 cho các mã bưu điện khác. Sau đó kết hợp với dữ liệu chi tiết hóa đơn (df_receipt) và đếm số khách hàng có doanh số bán hàng trong toàn bộ giai đoạn.

# %%
# 1
(
    df_customer.assign (
        postal_flg = np.where(df_customer['postal_cd'].str[0:3].astype(int).between(100, 209), 1, 0)
    )[['postal_flg', 'customer_id']]
    .merge(df_receipt, how = 'inner', on='customer_id')
    .groupby('postal_flg').agg({'customer_id': 'nunique'})
).head()
# Out:
#             customer_id
# postal_flg
# 0                   191
# 1                   229

# %%
# 2
df_tmp = df_customer[['customer_id', 'postal_cd']].copy()
print(len(df_tmp))

df_tmp['postal_flg'] = np.where(df_customer['postal_cd'].str[0:3].astype(int).between(100, 209), 1, 0)
print(len(df_tmp))

pd.merge(df_tmp, df_receipt, how="inner", on='customer_id').groupby('postal_flg').agg({'customer_id': 'nunique'}).head(10)
# Out:
# 1099
# 1099
#             customer_id
# postal_flg
# 0                   191
# 1                   229

# %% [markdown]
# ---
# > P-054:
# Đếm số lượng khách hàng (df_customer) sống ở các tỉnh Saitama, Chiba, Tokyo, và Kanagawa, tạo mã cho từng tỉnh, hiển thị 10 bản ghi đầu tiên cùng với địa chỉ và mã tỉnh tương ứng. Gán mã Saitama là 11, Chiba là 12, Tokyo là 13, và Kanagawa là 14.

# %% [markdown]
# **Memo:**
# * `r'...'`: Đây là một raw string literal trong Python, giúp cho các ký tự đặc biệt trong regex được xử lý chính xác mà không cần phải dùng dấu \ để escape chúng.
# * `\b`: Đây là một word boundary (ranh giới từ), đảm bảo rằng chuỗi cần tìm là một từ hoàn chỉnh và không phải là một phần của một từ dài hơn.
# * `(Tokyo|Kanagawa|Saitama|Chiba)`: Đây là một nhóm chứa các lựa chọn thay thế (alternatives). Regex này sẽ khớp với bất kỳ từ nào trong số các từ được liệt kê, nghĩa là nó sẽ khớp với "Tokyo", "Kanagawa", "Saitama", hoặc "Chiba".

# %%
prefecture_pattern = r'\b(Tokyo|Kanagawa|Saitama|Chiba)\b'
mapping_dict = {
    "Saitama":11,
    "Chiba": 12,
    "Tokyo": 13,
    "Kanagawa": 14
}

df_customer.assign (
    prefecture_cd = df_customer['address'].str.extract(prefecture_pattern, expand = False).map(mapping_dict)
)[['customer_id', 'address', 'prefecture_cd']].tail(10)
# Out:
#          customer_id                                            address  \
# 1089  CS013313000153          Shibaen, Narashino City, Chiba Prefecture
# 1090  CS013513000061        Sodegaura, Narashino City, Chiba Prefecture
# 1091  CS019414000068                     Kotake -cho, Nerima -ku, Tokyo
# 1092  CS002415000029           Kamisui Minami -cho, Kodaira City, Tokyo
# 1093  CS003313000470                       Motoizumi, Komae City, Tokyo
# 1094  CS039511000062                          Wada, Suginami -ku, Tokyo
# 1095  CS008404000002                         Seijo, Setagaya -ku, Tokyo
# 1096  CS015602000008                            Oshima, Koto -ku, Tokyo
# 1097  CS011615000007  Shimoda -cho, Kohoku -ku, Yokohama -shi, Kanagawa
# 1098  CS025511000066         Kamewada, Yamato City, Kanagawa Prefecture
#
#       prefecture_cd
# 1089           12.0
# 1090           12.0
# 1091           13.0
# 1092           13.0
# 1093           13.0
# 1094           13.0
# 1095           13.0
# 1096           13.0
# 1097           14.0
# 1098           14.0

# %% [markdown]
# ---
# > P-055: Tổng hợp số tiền bán hàng (amount) trong dữ liệu chi tiết hóa đơn (df_receipt) theo từng khách hàng (customer_id), và tính toán bốn phân vị (quantile) của tổng số tiền bán hàng. Sau đó, gán giá trị hạng mục cho tổng số tiền bán hàng của mỗi khách hàng theo các tiêu chí sau và hiển thị cùng với ID khách hàng và tổng số tiền bán hàng, tổng cộng 10 mục. Giá trị hạng mục được gán từ 1 đến 4 như sau:
# >
# > - Nhỏ hơn hoặc bằng phân vị thứ nhất Q1: 1
# > - Lớn hơn phân vị thứ nhất và nhỏ hơn hoặc bằng phân vị thứ hai Q2: 2
# > - Lớn hơn phân vị thứ hai và nhỏ hơn hoặc bằng phân vị thứ ba Q3: 3
# > - Lớn hơn phân vị thứ ba Q4: 4

# %%
# 1
df_tmp = df_receipt[['customer_id', 'amount']].groupby('customer_id').sum().reset_index()
pct25 = np.quantile(df_tmp['amount'], 0.25)
pct50 = np.quantile(df_tmp['amount'], 0.50)
pct75 = np.quantile(df_tmp['amount'], 0.75)

pct_max = df_tmp['amount'].max()

df_tmp.loc[:, 'quantile'] = pd.cut(df_tmp['amount'], [0.0, pct25, pct50, pct75, pct_max+0.1], right=False)
df_tmp.loc[:, 'pct_group'] = df_tmp.groupby('quantile').ngroup()+1

df_tmp.head(10)
# Out:
#       customer_id  amount          quantile  pct_group
# 0  CS001113000004    1298   [548.5, 1478.0)          2
# 1  CS001114000005     626   [548.5, 1478.0)          2
# 2  CS001115000010    3044  [1478.0, 3651.0)          3
# 3  CS001205000004    1988  [1478.0, 3651.0)          3
# 4  CS001205000006    3337  [1478.0, 3651.0)          3
# 5  CS001211000025     456      [0.0, 548.5)          1
# 6  CS001212000027     448      [0.0, 548.5)          1
# 7  CS001212000031     296      [0.0, 548.5)          1
# 8  CS001212000046     228      [0.0, 548.5)          1
# 9  CS001212000070     456      [0.0, 548.5)          1

# %%
pd.cut(df_tmp['amount'], [0.0, pct25, pct50, pct75, pct_max+0.1], right=False)
# Out:
# 0            [548.5, 1478.0)
# 1            [548.5, 1478.0)
# 2           [1478.0, 3651.0)
# 3           [1478.0, 3651.0)
# 4           [1478.0, 3651.0)
#                 ...
# 8302         [548.5, 1478.0)
# 8303            [0.0, 548.5)
# 8304            [0.0, 548.5)
# 8305            [0.0, 548.5)
# 8306    [3651.0, 12395003.1)
# Name: amount, Length: 8307, dtype: category
# Categories (4, interval[float64, left]): [[0.0, 548.5) < [548.5, 1478.0) < [1478.0, 3651.0) < [3651.0, 12395003.1)]

# %%
# 2
# Sử dụng pcut()
df_tmp = df_receipt[['customer_id', 'amount']].groupby('customer_id').sum()
df_tmp['quantile'], bins = \
pd.qcut(df_receipt.groupby('customer_id')['amount'].sum(), 4, retbins=True)

df_tmp['pct_group'] = df_tmp.groupby('quantile', observed=False).ngroup()+1

df_tmp.reset_index(inplace=True)
display(df_tmp.head(10))

print('quantiles:', bins)
# Out:
#       customer_id  amount          quantile  pct_group
# 0  CS001113000004    1298   (548.5, 1478.0]          2
# 1  CS001114000005     626   (548.5, 1478.0]          2
# 2  CS001115000010    3044  (1478.0, 3651.0]          3
# 3  CS001205000004    1988  (1478.0, 3651.0]          3
# 4  CS001205000006    3337  (1478.0, 3651.0]          3
# 5  CS001211000025     456   (69.999, 548.5]          1
# 6  CS001212000027     448   (69.999, 548.5]          1
# 7  CS001212000031     296   (69.999, 548.5]          1
# 8  CS001212000046     228   (69.999, 548.5]          1
# 9  CS001212000070     456   (69.999, 548.5]          1
# quantiles: [7.0000000e+01 5.4850000e+02 1.4780000e+03 3.6510000e+03 1.2395003e+07]

# %% [markdown]
# ---
# > P-056: Từ tuổi (age) trong dữ liệu khách hàng (df_customer), tính thập kỷ theo khoảng 10 năm, và hiển thị cùng với ID khách hàng (customer_id) và ngày sinh (birth_day), tổng cộng 10 mục. Tuy nhiên, tất cả những khách hàng từ 60 tuổi trở lên đều được xếp vào thập kỷ 60. Tên của các hạng mục thập kỷ có thể tùy chọn.

# %%
df_customer_era = (
    df_customer.assign(
        era = df_customer['age'].apply(lambda x: np.floor(x/10)*10).astype('int')
    )[['customer_id', 'birth_day', 'era']]
)
df_customer_era.head(10)
# Out:
#       customer_id   birth_day  era
# 0  CS019415000154  1971-07-08   40
# 1  CS008514000047  1962-04-03   50
# 2  CS038615000025  1955-06-29   60
# 3  CS004615000296  1950-02-23   60
# 4  CS033515000071  1966-04-30   50
# 5  CS041402000009  1973-10-30   40
# 6  CS001603000084  1956-08-02   60
# 7  CS022515000271  1966-08-27   50
# 8  CS020412000046  1971-12-09   40
# 9  CS002515000759  1963-07-15   50

# %% [markdown]
# ---
# > P-057: Từ kết quả của P-056 và mã giới tính (gender_cd), tạo dữ liệu hạng mục mới biểu thị các tổ hợp của giới tính và thập kỷ tuổi, và hiển thị 10 mục. Giá trị của các hạng mục tổ hợp có thể tùy chọn.

# %%
# 1
df_customer_era = (
    df_customer.assign(
        era = df_customer['age'].apply(lambda x: np.floor(x/10)*10).astype('int')
    )[['customer_id', 'birth_day','gender_cd', 'era']]
)
df_customer_era['combined'] = df_customer_era.apply(lambda row: str(row['gender_cd'] + str(row['era'])), axis=1)
df_customer_era.head(10)
# Out:
#       customer_id   birth_day gender_cd  era combined
# 0  CS019415000154  1971-07-08         9   40      940
# 1  CS008514000047  1962-04-03         1   50      150
# 2  CS038615000025  1955-06-29         1   60      160
# 3  CS004615000296  1950-02-23         1   60      160
# 4  CS033515000071  1966-04-30         1   50      150
# 5  CS041402000009  1973-10-30         0   40      040
# 6  CS001603000084  1956-08-02         0   60      060
# 7  CS022515000271  1966-08-27         1   50      150
# 8  CS020412000046  1971-12-09         1   40      140
# 9  CS002515000759  1963-07-15         1   50      150

# %%
# 2
df_customer_era = df_customer[['customer_id', 'birth_day']].copy()

df_customer_era['era'] = df_customer['age'].\
                            apply(lambda x : min(math.floor(x / 10) * 10, 60))

df_customer_era['gender_era'] = \
    df_customer['gender_cd'] + df_customer_era['era'].astype('str').str.zfill(2)

df_customer_era.head(10)
# Out:
#       customer_id   birth_day  era gender_era
# 0  CS019415000154  1971-07-08   40        940
# 1  CS008514000047  1962-04-03   50        150
# 2  CS038615000025  1955-06-29   60        160
# 3  CS004615000296  1950-02-23   60        160
# 4  CS033515000071  1966-04-30   50        150
# 5  CS041402000009  1973-10-30   40        040
# 6  CS001603000084  1956-08-02   60        060
# 7  CS022515000271  1966-08-27   50        150
# 8  CS020412000046  1971-12-09   40        140
# 9  CS002515000759  1963-07-15   50        150

# %% [markdown]
# ---
# > P-058: Biến đổi mã giới tính (gender_cd) trong dữ liệu khách hàng (df_customer) thành biến giả (dummy variable) và hiển thị cùng với ID khách hàng (customer_id), tổng cộng 10 mục.

# %%
# 1
pd.get_dummies(df_customer[['customer_id', 'gender_cd']], columns=['gender_cd'], dtype='int').head(10)
# Out:
#       customer_id  gender_cd_0  gender_cd_1  gender_cd_9
# 0  CS019415000154            0            0            1
# 1  CS008514000047            0            1            0
# 2  CS038615000025            0            1            0
# 3  CS004615000296            0            1            0
# 4  CS033515000071            0            1            0
# 5  CS041402000009            1            0            0
# 6  CS001603000084            1            0            0
# 7  CS022515000271            0            1            0
# 8  CS020412000046            0            1            0
# 9  CS002515000759            0            1            0

# %%
# 2
pd.get_dummies(df_customer[['customer_id', 'gender_cd']],
               columns=['gender_cd'], 
               drop_first=True, prefix='gen', prefix_sep='_').head(10)
# Out:
#       customer_id  gen_1  gen_9
# 0  CS019415000154  False   True
# 1  CS008514000047   True  False
# 2  CS038615000025   True  False
# 3  CS004615000296   True  False
# 4  CS033515000071   True  False
# 5  CS041402000009  False  False
# 6  CS001603000084  False  False
# 7  CS022515000271   True  False
# 8  CS020412000046   True  False
# 9  CS002515000759   True  False

# %% [markdown]
# ---
# > P-059: Tổng hợp số tiền bán hàng (amount) trong dữ liệu chi tiết hóa đơn (df_receipt) theo từng khách hàng (customer_id) và tính tổng số tiền bán hàng trung bình. Chuẩn hóa tổng số tiền bán hàng trung bình cho mỗi khách hàng, hiển thị ID khách hàng và tổng số tiền bán hàng cùng với 10 mục. Việc chuẩn hóa có thể sử dụng độ lệch chuẩn hoặc căn bậc hai của độ lệch chuẩn. Tuy nhiên, loại trừ các khách hàng không phải là thành viên (có ID khách hàng bắt đầu bằng "Z").

# %% [markdown]
# TIPS:
# - Hàm query() của pandas hỗ trợ sử dụng động cơ "python" hoặc "numexpr". Động cơ mặc định là "numexpr", nhưng có thể thay đổi bằng cách đặt "pandas.options.mode.chained_assignment = None".
# - Ngoài ra, có thể sử dụng truy vấn như 'df.query("column_name > 5")' để lọc dữ liệu.

# %%
# 1
from sklearn import preprocessing
# loại trừ các khách hàng không phải là thành viên (có ID khách hàng bắt đầu bằng "Z"

df_sales_amount = (
    df_receipt[~ df_receipt['customer_id'].str.startswith("Z")]
    .groupby('customer_id')
    .agg({'amount':'sum'})
    .reset_index()    
)

df_sales_amount['std_amount'] = preprocessing.scale(df_sales_amount['amount'])

df_sales_amount.head()
# Out:
#       customer_id  amount  std_amount
# 0  CS001113000004    1298   -0.459378
# 1  CS001114000005     626   -0.706390
# 2  CS001115000010    3044    0.182413
# 3  CS001205000004    1988   -0.205749
# 4  CS001205000006    3337    0.290114

# %%
# 2
from sklearn.preprocessing import StandardScaler

df_sales_amount = (
    df_receipt[~ df_receipt['customer_id'].str.startswith("Z")]
    .groupby('customer_id')
    .agg({'amount':'sum'})
    .reset_index()    
)

scaler = StandardScaler()

df_sales_amount['std_amount'] = scaler.fit_transform(df_sales_amount[['amount']])
df_sales_amount.head()
# Out:
#       customer_id  amount  std_amount
# 0  CS001113000004    1298   -0.459378
# 1  CS001114000005     626   -0.706390
# 2  CS001115000010    3044    0.182413
# 3  CS001205000004    1988   -0.205749
# 4  CS001205000006    3337    0.290114

# %% [markdown]
# ---
# > P-060: Tổng hợp số tiền bán hàng (amount) trong dữ liệu chi tiết hóa đơn (df_receipt) theo từng khách hàng (customer_id) và chuẩn hóa tổng số tiền bán hàng theo giá trị tối đa. Hiển thị ID khách hàng và tổng số tiền bán hàng cùng với 10 mục. Tuy nhiên, loại trừ các khách hàng không phải là thành viên (có ID khách hàng bắt đầu bằng "Z").

# %%
from sklearn.preprocessing import MinMaxScaler

df_sales_amount = (
    df_receipt[~ df_receipt['customer_id'].str.startswith("Z")]
    .groupby('customer_id')
    .agg({'amount':'sum'})
    .reset_index()    
)

scaler = MinMaxScaler()
df_sales_amount['std_amount'] = scaler.fit_transform(df_sales_amount[['amount']])
df_sales_amount.head()
# Out:
#       customer_id  amount  std_amount
# 0  CS001113000004    1298    0.053354
# 1  CS001114000005     626    0.024157
# 2  CS001115000010    3044    0.129214
# 3  CS001205000004    1988    0.083333
# 4  CS001205000006    3337    0.141945

# %% [markdown]
# ### Phần 4: 61 - 80

# %% [markdown]
# ---
# > P-061: Tổng hợp số tiền bán hàng (amount) trong dữ liệu chi tiết hóa đơn (df_receipt) theo từng khách hàng (customer_id) và chuẩn hóa tổng số tiền bán hàng bằng cách lấy logarithm (log10). Hiển thị ID khách hàng và tổng số tiền bán hàng cùng với 10 mục. Tuy nhiên, loại trừ các khách hàng không phải là thành viên (có ID khách hàng bắt đầu bằng "Z").

# %%
df_sales_amount = (
    df_receipt.query("not customer_id.str.startswith('Z')")
    .groupby("customer_id")
    .agg({'amount': 'sum'})
    .reset_index()
    .assign(
        log_amount = lambda df: np.log10(df['amount'] + 1)
    ).head(10)
)
df_sales_amount
# Out:
#       customer_id  amount  log_amount
# 0  CS001113000004    1298    3.113609
# 1  CS001114000005     626    2.797268
# 2  CS001115000010    3044    3.483587
# 3  CS001205000004    1988    3.298635
# 4  CS001205000006    3337    3.523486
# 5  CS001211000025     456    2.659916
# 6  CS001212000027     448    2.652246
# 7  CS001212000031     296    2.472756
# 8  CS001212000046     228    2.359835
# 9  CS001212000070     456    2.659916

# %% [markdown]
# ---
# > P-062: Tổng hợp số tiền bán hàng (amount) trong dữ liệu chi tiết hóa đơn (df_receipt) theo từng khách hàng (customer_id) và chuẩn hóa tổng số tiền bán hàng bằng cách lấy logarithm tự nhiên (ln). Hiển thị ID khách hàng và tổng số tiền bán hàng cùng với 10 mục. Tuy nhiên, loại trừ các khách hàng không phải là thành viên (có ID khách hàng bắt đầu bằng "Z").

# %%
df_sales_amount = (
    df_receipt.query("not customer_id.str.startswith('Z')")
    .groupby("customer_id")
    .agg({'amount': 'sum'})
    .reset_index()
    .assign(
        log_amount = lambda df: np.log(df['amount'] + 1)
    ).head(10)
)
df_sales_amount
# Out:
#       customer_id  amount  log_amount
# 0  CS001113000004    1298    7.169350
# 1  CS001114000005     626    6.440947
# 2  CS001115000010    3044    8.021256
# 3  CS001205000004    1988    7.595387
# 4  CS001205000006    3337    8.113127
# 5  CS001211000025     456    6.124683
# 6  CS001212000027     448    6.107023
# 7  CS001212000031     296    5.693732
# 8  CS001212000046     228    5.433722
# 9  CS001212000070     456    6.124683

# %% [markdown]
# ---
# > P-063: Từ dữ liệu sản phẩm (df_product), tính lợi nhuận của mỗi sản phẩm dựa trên đơn giá (unit_price) và giá gốc (unit_cost), và hiển thị kết quả của 10 mục.

# %%
df_product.assign (
    unit_profit = lambda df : df['unit_price'] - df['unit_cost']
).head(10)
# Out:
#    product_cd category_major_cd category_medium_cd category_small_cd  \
# 0  P040101001                04               0401            040101
# 1  P040101002                04               0401            040101
# 2  P040101003                04               0401            040101
# 3  P040101004                04               0401            040101
# 4  P040101005                04               0401            040101
# 5  P040101006                04               0401            040101
# 6  P040101007                04               0401            040101
# 7  P040101008                04               0401            040101
# 8  P040101009                04               0401            040101
# 9  P040101010                04               0401            040101
#
#    unit_price  unit_cost  unit_profit
# 0       198.0      149.0         49.0
# 1       218.0      164.0         54.0
# 2       230.0      173.0         57.0
# 3       248.0      186.0         62.0
# 4       268.0      201.0         67.0
# 5       298.0      224.0         74.0
# 6       338.0      254.0         84.0
# 7       420.0      315.0        105.0
# 8       498.0      374.0        124.0
# 9       580.0      435.0        145.0

# %% [markdown]
# ---
# > P-064: Từ đơn giá (unit_price) và giá gốc (unit_cost) trong dữ liệu sản phẩm (df_product), tính toán tỷ lệ lợi nhuận trung bình của mỗi sản phẩm. Lưu ý rằng có thể có các giá trị thiếu trong đơn giá và giá gốc.

# %%
df_tmp = df_product.copy()

df_tmp['unit_profit_rate'] = (df_tmp['unit_price'] - df_tmp['unit_cost']) / df_tmp['unit_price']

print(df_tmp['unit_profit_rate'].mean(skipna=True))
# Out:
# 0.24911389885177

# %% [markdown]
# ---
# > P-065: Đối với mỗi sản phẩm trong dữ liệu sản phẩm (df_product), tính toán đơn giá mới sao cho tỷ lệ lợi nhuận là 30%. Lưu ý làm tròn bỏ các số lẻ dưới 1 yên. Hiển thị kết quả 10 mục và xác nhận rằng tỷ lệ lợi nhuận xấp xỉ 30%. Lưu ý rằng có thể có các giá trị thiếu trong đơn giá (unit_price) và giá gốc (unit_cost).

# %%
df_tmp = (
    df_product[['product_cd', 'unit_price', 'unit_cost']]
    .assign(
        new_price = lambda df: np.floor(df['unit_cost'] / 0.7),
        new_profit_rate = lambda df: (df['new_price'] - df['unit_cost']) / df['new_price']
    )
)
df_tmp.head(10)
# Out:
#    product_cd  unit_price  unit_cost  new_price  new_profit_rate
# 0  P040101001       198.0      149.0      212.0         0.297170
# 1  P040101002       218.0      164.0      234.0         0.299145
# 2  P040101003       230.0      173.0      247.0         0.299595
# 3  P040101004       248.0      186.0      265.0         0.298113
# 4  P040101005       268.0      201.0      287.0         0.299652
# 5  P040101006       298.0      224.0      320.0         0.300000
# 6  P040101007       338.0      254.0      362.0         0.298343
# 7  P040101008       420.0      315.0      450.0         0.300000
# 8  P040101009       498.0      374.0      534.0         0.299625
# 9  P040101010       580.0      435.0      621.0         0.299517

# %% [markdown]
# ---
# > P-066: Đối với mỗi sản phẩm trong dữ liệu sản phẩm (df_product), tính toán đơn giá mới sao cho tỷ lệ lợi nhuận là 30%. Lần này, làm tròn đến số nguyên gần nhất (có thể làm tròn lên hoặc làm tròn xuống). Hiển thị kết quả 10 mục và xác nhận rằng tỷ lệ lợi nhuận xấp xỉ 30%. Lưu ý rằng có thể có các giá trị thiếu trong đơn giá (unit_price) và giá gốc (unit_cost).

# %%
df_tmp = (
    df_product[['product_cd', 'unit_price', 'unit_cost']]
    .assign(
        new_price = lambda df: np.round(df['unit_cost'] / 0.7),
        new_profit_rate = lambda df: (df['new_price'] - df['unit_cost']) / df['new_price']
    )
)
df_tmp.head(10)
# Out:
#    product_cd  unit_price  unit_cost  new_price  new_profit_rate
# 0  P040101001       198.0      149.0      213.0         0.300469
# 1  P040101002       218.0      164.0      234.0         0.299145
# 2  P040101003       230.0      173.0      247.0         0.299595
# 3  P040101004       248.0      186.0      266.0         0.300752
# 4  P040101005       268.0      201.0      287.0         0.299652
# 5  P040101006       298.0      224.0      320.0         0.300000
# 6  P040101007       338.0      254.0      363.0         0.300275
# 7  P040101008       420.0      315.0      450.0         0.300000
# 8  P040101009       498.0      374.0      534.0         0.299625
# 9  P040101010       580.0      435.0      621.0         0.299517

# %% [markdown]
# ---
# > P-067: Đối với mỗi sản phẩm trong dữ liệu sản phẩm (df_product), tính toán đơn giá mới sao cho tỷ lệ lợi nhuận là 30%. Lần này, làm tròn lên đối với các số lẻ dưới 1 yên. Hiển thị kết quả 10 mục và xác nhận rằng tỷ lệ lợi nhuận xấp xỉ 30%. Lưu ý rằng có thể có các giá trị thiếu trong đơn giá (unit_price) và giá gốc (unit_cost).

# %%
df_tmp = (
    df_product[['product_cd', 'unit_price', 'unit_cost']]
    .assign(
        new_price = lambda df: np.ceil(df['unit_cost'] / 0.7),
        new_profit_rate = lambda df: (df['new_price'] - df['unit_cost']) / df['new_price']
    )
)
df_tmp.head(10)
# Out:
#    product_cd  unit_price  unit_cost  new_price  new_profit_rate
# 0  P040101001       198.0      149.0      213.0         0.300469
# 1  P040101002       218.0      164.0      235.0         0.302128
# 2  P040101003       230.0      173.0      248.0         0.302419
# 3  P040101004       248.0      186.0      266.0         0.300752
# 4  P040101005       268.0      201.0      288.0         0.302083
# 5  P040101006       298.0      224.0      320.0         0.300000
# 6  P040101007       338.0      254.0      363.0         0.300275
# 7  P040101008       420.0      315.0      451.0         0.301552
# 8  P040101009       498.0      374.0      535.0         0.300935
# 9  P040101010       580.0      435.0      622.0         0.300643

# %% [markdown]
# ---
# > P-068: Đối với mỗi sản phẩm trong dữ liệu sản phẩm (df_product), tính toán giá sau khi đã bao gồm thuế tiêu dùng 10%. Làm tròn bỏ các số lẻ dưới 1 yên. Hiển thị kết quả 10 mục. Lưu ý rằng có thể có các giá trị thiếu trong đơn giá (unit_price).

# %%
df_tmp = (
    df_product[['product_cd', 'unit_price']]
    .assign(
        tax_price = lambda df: np.floor(df['unit_price'] * 1.1)
    )
)
df_tmp.head(10)
# Out:
#    product_cd  unit_price  tax_price
# 0  P040101001       198.0      217.0
# 1  P040101002       218.0      239.0
# 2  P040101003       230.0      253.0
# 3  P040101004       248.0      272.0
# 4  P040101005       268.0      294.0
# 5  P040101006       298.0      327.0
# 6  P040101007       338.0      371.0
# 7  P040101008       420.0      462.0
# 8  P040101009       498.0      547.0
# 9  P040101010       580.0      638.0

# %% [markdown]
# ---
# > P-069: Kết hợp dữ liệu chi tiết hóa đơn (df_receipt) và dữ liệu sản phẩm (df_product), tính tổng số tiền bán hàng của tất cả sản phẩm cho mỗi khách hàng, và tổng số tiền bán hàng của các sản phẩm thuộc mã phân loại lớn (category_major_cd) "07" (đồ uống). Sau đó, tính tỷ lệ giữa hai tổng số tiền này. Chỉ trích xuất các khách hàng có doanh số bán hàng cho mã phân loại lớn "07". Hiển thị 10 kết quả.

# %%
df_tmp1 = (
    df_receipt.groupby('customer_id').agg(sum_all=("amount", "sum"))
    .reset_index()
)

df_tmp2 = (
    pd.merge(df_receipt, 
             df_product.query("category_major_cd == '07'"), 
             how="inner", 
             on="product_cd")
    .groupby("customer_id")
    .agg(sum_07=("amount", "sum"))
    .reset_index()
)
df_tmp3 = (
    pd.merge(df_tmp1, df_tmp2, how="inner", on='customer_id')
)
df_tmp3['sale_rates'] = df_tmp3['sum_07'] / df_tmp3['sum_all']
df_tmp3.head(10)
# Out:
#       customer_id  sum_all  sum_07  sale_rates
# 0  CS001113000004     1298    1298    1.000000
# 1  CS001114000005      626     486    0.776358
# 2  CS001115000010     3044    2694    0.885020
# 3  CS001205000004     1988     346    0.174044
# 4  CS001205000006     3337    2004    0.600539
# 5  CS001212000027      448     200    0.446429
# 6  CS001212000031      296     296    1.000000
# 7  CS001212000046      228     108    0.473684
# 8  CS001212000070      456     308    0.675439
# 9  CS001213000018      243     145    0.596708

# %% [markdown]
# ---
# > P-070: Đối với ngày bán hàng (sales_ymd) trong dữ liệu chi tiết hóa đơn (df_receipt), kết hợp với ngày đăng ký thành viên (application_date) trong dữ liệu khách hàng (df_customer), tính khoảng thời gian giữa hai ngày này. Hiển thị ID khách hàng (customer_id), ngày bán hàng, ngày đăng ký thành viên và khoảng thời gian đó, tổng cộng 10 mục. Lưu ý rằng sales_ymd là giá trị số, còn application_date được lưu trữ dưới dạng chuỗi văn bản.

# %%
#1
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_days'] = df_tmp['sales_ymd'] - df_tmp['application_date']
df_tmp['elapsed_days'] = df_tmp['elapsed_days'].dt.days

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date  elapsed_days
# 0  CS014415000077 2017-06-19       2015-09-23           635
# 1  CS024514000012 2019-06-21       2015-12-25          1274
# 2  CS019414000068 2018-06-13       2015-03-25          1176
# 3  CS004415000050 2018-04-25       2015-04-26          1095
# 4  CS016415000215 2017-06-11       2014-11-05           949
# 5  CS013415000041 2018-11-27       2015-05-04          1303
# 6  CS009314000042 2017-03-15       2015-03-31           715
# 7  CS010513000187 2019-08-08       2015-07-10          1490
# 8  CS039415000073 2018-05-28       2015-03-22          1163
# 9  CS006514000034 2019-05-24       2015-02-02          1572

# %%
#2
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
    .assign (
        elapsed_days = lambda df: (pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")\
        - pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")).dt.days
    )
)

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd  application_date  elapsed_days
# 0  CS014415000077   20170619          20150923           635
# 1  CS024514000012   20190621          20151225          1274
# 2  CS019414000068   20180613          20150325          1176
# 3  CS004415000050   20180425          20150426          1095
# 4  CS016415000215   20170611          20141105           949
# 5  CS013415000041   20181127          20150504          1303
# 6  CS009314000042   20170315          20150331           715
# 7  CS010513000187   20190808          20150710          1490
# 8  CS039415000073   20180528          20150322          1163
# 9  CS006514000034   20190524          20150202          1572

# %% [markdown]
# ---
# > P-071: Đối với ngày bán hàng (sales_ymd) của dữ liệu chi tiết hóa đơn (df_receipt), tính số tháng kể từ ngày đăng ký thành viên (application_date) của dữ liệu khách hàng (df_customer) và hiển thị cùng với ID khách hàng (customer_id), ngày bán hàng và ngày đăng ký thành viên, mỗi thứ 10 mục. Lưu ý rằng sales_ymd là giá trị số và application_date lưu giữ dữ liệu dưới dạng chuỗi. Bỏ qua những mục dưới 1 tháng.

# %%
# 1
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_days'] = df_tmp['sales_ymd'] - df_tmp['application_date']
df_tmp['elapsed_days'] = df_tmp['elapsed_days'].dt.days
# df_tmp['elapsed_months'] = df_tmp['sales_ymd'] - df_tmp['application_date']
df_tmp['elapsed_months'] = np.floor(df_tmp['elapsed_days'] / 365 * 12).astype('int')

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date  elapsed_days  elapsed_months
# 0  CS014415000077 2017-06-19       2015-09-23           635              20
# 1  CS024514000012 2019-06-21       2015-12-25          1274              41
# 2  CS019414000068 2018-06-13       2015-03-25          1176              38
# 3  CS004415000050 2018-04-25       2015-04-26          1095              36
# 4  CS016415000215 2017-06-11       2014-11-05           949              31
# 5  CS013415000041 2018-11-27       2015-05-04          1303              42
# 6  CS009314000042 2017-03-15       2015-03-31           715              23
# 7  CS010513000187 2019-08-08       2015-07-10          1490              48
# 8  CS039415000073 2018-05-28       2015-03-22          1163              38
# 9  CS006514000034 2019-05-24       2015-02-02          1572              51

# %%
# 2
from dateutil.relativedelta import relativedelta
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_days'] = df_tmp['sales_ymd'] - df_tmp['application_date']
df_tmp['elapsed_days'] = df_tmp['elapsed_days'].dt.days
df_tmp['elapsed_months'] = df_tmp[['sales_ymd', 'application_date']]\
                .apply(lambda x: relativedelta(x[0], x[1]).years * 12 + \
                                  relativedelta(x[0], x[1]).months, axis=1)

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date  elapsed_days  elapsed_months
# 0  CS014415000077 2017-06-19       2015-09-23           635              20
# 1  CS024514000012 2019-06-21       2015-12-25          1274              41
# 2  CS019414000068 2018-06-13       2015-03-25          1176              38
# 3  CS004415000050 2018-04-25       2015-04-26          1095              35
# 4  CS016415000215 2017-06-11       2014-11-05           949              31
# 5  CS013415000041 2018-11-27       2015-05-04          1303              42
# 6  CS009314000042 2017-03-15       2015-03-31           715              23
# 7  CS010513000187 2019-08-08       2015-07-10          1490              48
# 8  CS039415000073 2018-05-28       2015-03-22          1163              38
# 9  CS006514000034 2019-05-24       2015-02-02          1572              51

# %% [markdown]
# ---
# > P-072: Đối với ngày bán hàng (sales_ymd) của dữ liệu chi tiết hóa đơn (df_receipt), tính số năm kể từ ngày đăng ký thành viên (application_date) của dữ liệu khách hàng (df_customer) và hiển thị cùng với ID khách hàng (customer_id), ngày bán hàng và ngày đăng ký thành viên, mỗi thứ 10 mục. Lưu ý rằng sales_ymd là giá trị số và application_date lưu giữ dữ liệu dưới dạng chuỗi. Bỏ qua những mục dưới 1 năm.

# %%
# 1
df_tmp = df_receipt[['customer_id', 'sales_ymd']].drop_duplicates()
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_days'] = df_tmp['sales_ymd'] - df_tmp['application_date']
df_tmp['elapsed_days'] = df_tmp['elapsed_days'].dt.days
df_tmp['elapsed_years'] = df_tmp['elapsed_days'] // 365

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date  elapsed_days  elapsed_years
# 0  CS014415000077 2017-06-19       2015-09-23           635              1
# 1  CS024514000012 2019-06-21       2015-12-25          1274              3
# 2  CS019414000068 2018-06-13       2015-03-25          1176              3
# 3  CS004415000050 2018-04-25       2015-04-26          1095              3
# 4  CS016415000215 2017-06-11       2014-11-05           949              2
# 5  CS013415000041 2018-11-27       2015-05-04          1303              3
# 6  CS009314000042 2017-03-15       2015-03-31           715              1
# 7  CS010513000187 2019-08-08       2015-07-10          1490              4
# 8  CS039415000073 2018-05-28       2015-03-22          1163              3
# 9  CS006514000034 2019-05-24       2015-02-02          1572              4

# %%
# 2
from dateutil.relativedelta import relativedelta
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_days'] = df_tmp['sales_ymd'] - df_tmp['application_date']
df_tmp['elapsed_days'] = df_tmp['elapsed_days'].dt.days
df_tmp['elapsed_years'] = df_tmp[['sales_ymd', 'application_date']]\
                .apply(lambda x: relativedelta(x[0], x[1]).years, axis=1)

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date  elapsed_days  elapsed_years
# 0  CS014415000077 2017-06-19       2015-09-23           635              1
# 1  CS024514000012 2019-06-21       2015-12-25          1274              3
# 2  CS019414000068 2018-06-13       2015-03-25          1176              3
# 3  CS004415000050 2018-04-25       2015-04-26          1095              2
# 4  CS016415000215 2017-06-11       2014-11-05           949              2
# 5  CS013415000041 2018-11-27       2015-05-04          1303              3
# 6  CS009314000042 2017-03-15       2015-03-31           715              1
# 7  CS010513000187 2019-08-08       2015-07-10          1490              4
# 8  CS039415000073 2018-05-28       2015-03-22          1163              3
# 9  CS006514000034 2019-05-24       2015-02-02          1572              4

# %% [markdown]
# ---
# > P-073: Đối với ngày bán hàng (sales_ymd) của dữ liệu chi tiết hóa đơn (df_receipt), tính khoảng thời gian từ ngày đăng ký thành viên (application_date) của dữ liệu khách hàng (df_customer) bằng giây kể từ Epoch và hiển thị cùng với ID khách hàng (customer_id), ngày bán hàng và ngày đăng ký thành viên, mỗi thứ 10 mục. (Lưu ý rằng sales_ymd là giá trị số và application_date lưu giữ dữ liệu dưới dạng chuỗi. Ngoài ra, vì không lưu giữ thông tin thời gian nên mỗi ngày được coi là 00:00:00).

# %%
# 1
# Hint: Chuyển đổi elapsed_days từ Timedelta sang giây (epoch time) bằng cách chia cho 10^9 (vì 1 giây = 10^9 nanosecond)
df_tmp = df_receipt[['customer_id', 'sales_ymd']].drop_duplicates()
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_days'] = df_tmp['sales_ymd'] - df_tmp['application_date']
# df_tmp['elapsed_days'] = df_tmp['elapsed_days'].dt.days
df_tmp['elapsed_epoch'] = (df_tmp['elapsed_days'] / 10**9).astype(np.int64)

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date elapsed_days  elapsed_epoch
# 0  CS014415000077 2017-06-19       2015-09-23     635 days       54864000
# 1  CS024514000012 2019-06-21       2015-12-25    1274 days      110073600
# 2  CS019414000068 2018-06-13       2015-03-25    1176 days      101606400
# 3  CS004415000050 2018-04-25       2015-04-26    1095 days       94608000
# 4  CS016415000215 2017-06-11       2014-11-05     949 days       81993600
# 5  CS013415000041 2018-11-27       2015-05-04    1303 days      112579200
# 6  CS009314000042 2017-03-15       2015-03-31     715 days       61776000
# 7  CS010513000187 2019-08-08       2015-07-10    1490 days      128736000
# 8  CS039415000073 2018-05-28       2015-03-22    1163 days      100483200
# 9  CS006514000034 2019-05-24       2015-02-02    1572 days      135820800

# %%
# 2
df_tmp = df_receipt[['customer_id', 'sales_ymd']].drop_duplicates()
df_tmp = (
    pd.merge(
        df_receipt[['customer_id', 'sales_ymd']],
        df_customer[['customer_id', 'application_date']],
        how='inner',
        on='customer_id'
    )
)

df_tmp['sales_ymd'] = pd.to_datetime(df_tmp['sales_ymd'], format="%Y%m%d")
df_tmp['application_date'] = pd.to_datetime(df_tmp['application_date'], format="%Y%m%d")
df_tmp['elapsed_epoch'] = (df_tmp['sales_ymd'].view(np.int64) - df_tmp['application_date'].view(np.int64)) / 10**9
# df_tmp['elapsed_epoch'] = (df_tmp['elapsed_days'] / 10**9).astype(np.int64)

df_tmp.head(10)
# Out:
#       customer_id  sales_ymd application_date  elapsed_epoch
# 0  CS014415000077 2017-06-19       2015-09-23     54864000.0
# 1  CS024514000012 2019-06-21       2015-12-25    110073600.0
# 2  CS019414000068 2018-06-13       2015-03-25    101606400.0
# 3  CS004415000050 2018-04-25       2015-04-26     94608000.0
# 4  CS016415000215 2017-06-11       2014-11-05     81993600.0
# 5  CS013415000041 2018-11-27       2015-05-04    112579200.0
# 6  CS009314000042 2017-03-15       2015-03-31     61776000.0
# 7  CS010513000187 2019-08-08       2015-07-10    128736000.0
# 8  CS039415000073 2018-05-28       2015-03-22    100483200.0
# 9  CS006514000034 2019-05-24       2015-02-02    135820800.0

# %% [markdown]
# ---
# > P-074: Đối với ngày bán hàng (sales_ymd) của dữ liệu chi tiết hóa đơn (df_receipt), tính số ngày đã trôi qua từ ngày thứ Hai trong tuần đó, và hiển thị cùng với ngày bán hàng và ngày thứ Hai trước đó, mỗi thứ 10 mục. (Lưu ý rằng sales_ymd là giá trị số và lưu giữ dữ liệu dưới dạng số).

# %%
# 1
import matplotlib.pyplot as plt
df_sample_store = (
    df_receipt[['store_cd', 'sales_ymd', 'amount']]
    .assign(
        sales_ymd = lambda df: pd.to_datetime(df_receipt['sales_ymd'], format='%Y%m%d'),
        elapsed_days = lambda df: df['sales_ymd'].dt.weekday,
        monday_of_week = lambda df: df['sales_ymd'] - df['elapsed_days'].apply(lambda x: pd.Timedelta(days=x))
    )
    .groupby(['store_cd','monday_of_week']).agg(weekly_sales=('amount', 'sum'))
    .reset_index()
    .query('store_cd=="S12007" & monday_of_week <= "2018-01-01"')
)

plt.figure(figsize=(6, 4))
plt.plot(df_sample_store['monday_of_week'], df_sample_store['weekly_sales'], marker='o', ls='--', c='b')

plt.xlabel('Week starting on monday')
plt.ylabel('Weekly sales')
plt.title('Weekly sales over time')

#rotation labels
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

df_sample_store.head(10)
# Out:
#   store_cd monday_of_week  weekly_sales
# 0   S12007     2017-01-02          4261
# 1   S12007     2017-01-09          5834
# 2   S12007     2017-01-16          3091
# 3   S12007     2017-01-23           916
# 4   S12007     2017-01-30          4592
# 5   S12007     2017-02-06          2097
# 6   S12007     2017-02-13          7054
# 7   S12007     2017-02-20          4044
# 8   S12007     2017-02-27          4650
# 9   S12007     2017-03-06          7056

# %%
# 1
df_tmp = (
    df_receipt[['sales_ymd']]
    .assign(
        sales_ymd = lambda df: pd.to_datetime(df_receipt['sales_ymd'], format='%Y%m%d'),
        elapsed_days = lambda df: df['sales_ymd'].dt.weekday,
        monday_of_week = df_tmp['sales_ymd'] - df_tmp['elapsed_days'].apply(lambda x: pd.Timedelta(days=x))
    )
)

# df_tmp['monday_of_week'] = df_tmp['sales_ymd'] - df_tmp['elapsed_days'].apply(lambda x: pd.Timedelta(days=x))

df_tmp.head(10)
# Out:
#    sales_ymd  elapsed_days monday_of_week
# 0 2018-11-03             5     2018-10-29
# 1 2018-11-18             6     2018-11-12
# 2 2017-07-12             2     2017-07-10
# 3 2019-02-05             1     2019-02-04
# 4 2018-08-21             1     2018-08-20
# 5 2019-06-05             2     2019-06-03
# 6 2018-12-05             2     2018-12-03
# 7 2019-09-22             6     2019-09-16
# 8 2017-05-04             3     2017-05-01
# 9 2019-10-10             3     2019-10-07

# %%
# 2
df_tmp = (
    df_receipt[['sales_ymd']]
    .assign(
        sales_ymd = lambda df: pd.to_datetime(df_receipt['sales_ymd'], format='%Y%m%d'),
        elapsed_days = lambda df: df['sales_ymd'].dt.weekday,
    )
)

df_tmp['monday_of_week'] = df_tmp['sales_ymd'].apply(lambda x: x - relativedelta(days=x.weekday()))

df_tmp.head(10)
# Out:
#    sales_ymd  elapsed_days monday_of_week
# 0 2018-11-03             5     2018-10-29
# 1 2018-11-18             6     2018-11-12
# 2 2017-07-12             2     2017-07-10
# 3 2019-02-05             1     2019-02-04
# 4 2018-08-21             1     2018-08-20
# 5 2019-06-05             2     2019-06-03
# 6 2018-12-05             2     2018-12-03
# 7 2019-09-22             6     2019-09-16
# 8 2017-05-04             3     2017-05-01
# 9 2019-10-10             3     2019-10-07

# %% [markdown]
# ---
# > P-075:
# Từ dữ liệu khách hàng (df_customer), lấy mẫu ngẫu nhiên 1% dữ liệu và hiển thị 10 bản ghi đầu tiên.

# %%
df_customer.sample(frac = 0.01).head(10)
# Out:
#         customer_id   customer_name gender_cd  gender   birth_day  age  \
# 893  CS002514000122  Michiko Otsuka         1    Male  1965-08-01   53
# 988  CS037205000004   Homeno Homeno         0  Female  1993-04-01   25
# 528  CS001301000040     Square sink         0  Female  1983-03-04   36
# 980  CS024414000072         Apricot         1    Male  1976-02-13   43
# 552  CS015715000024        Yoko Oda         1    Male  1939-10-23   79
# 132  CS012813000024   Nanami Tazaki         1    Male  1934-10-27   84
# 747  CS014415000037   Nana Minagawa         1    Male  1973-12-21   45
# 742  CS002313000294    Mami Shibata         1    Male  1987-07-13   31
# 772  CS009603000036            Lion         0  Female  1953-05-17   65
# 798  CS003513000543      Mahiru Abe         1    Male  1961-06-16   57
#
#     postal_cd                                            address  \
# 893  185-0013               Kokubunji -shi, Tokyo Nishiki Kokubo
# 988  135-0011                          Ogihashi, Koto -ku, Tokyo
# 528  212-0054  Kokura, Sachi -ku, Kawasaki City, Kanagawa Pre...
# 980  214-0036  Minaminata, Tama -ku, Kawasaki City, Kanagawa ...
# 552  135-0042                              Kiba, Koto -ku, Tokyo
# 132  231-0826    Honzaki Arai, Naka -ku, Yokohama -shi, Kanagawa
# 747  263-0051            Sono -cho, Inage -ku, Chiba -shi, Chiba
# 742  185-0022            Higashimotomachi, Kokubunji -shi, Tokyo
# 772  154-0014                     Shinmachi, Setagaya -ku, Tokyo
# 798  182-0007                       Kikunodai, Chofu City, Tokyo
#
#     application_store_cd  application_date     status_cd
# 893               S13002          20161211  4-20100509-2
# 988               S13037          20151230  C-20090415-A
# 528               S13001          20181003  0-00000000-0
# 980               S14024          20150412  E-20100908-E
# 552               S13015          20150910  0-00000000-0
# 132               S14012          20150130  0-00000000-0
# 747               S12014          20150507  E-20100220-E
# 742               S13002          20160630  0-00000000-0
# 772               S13009          20170601  0-00000000-0
# 798               S13003          20170413  0-00000000-0

# %% [markdown]
# ---
# > P-076: Từ dữ liệu khách hàng (df_customer), trích xuất ngẫu nhiên 10% dữ liệu dựa trên tỷ lệ của mã giới tính (gender_cd) và đếm số lượng theo từng mã giới tính.

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_customer, test_size=0.1,
                                    stratify=df_customer['gender_cd'])
df_test.groupby('gender_cd').agg({'customer_id':'count'})
# Out:
#            customer_id
# gender_cd
# 0                   14
# 1                   90
# 9                    6

# %% [markdown]
# ---
# > P-077: Tính tổng số tiền bán hàng theo từng đơn vị khách hàng từ dữ liệu chi tiết hóa đơn (df_receipt) và trích xuất các giá trị ngoại lệ của tổng số tiền bán hàng. Lưu ý rằng giá trị ngoại lệ là giá trị vượt quá 3σ từ trung bình sau khi chuẩn hóa tổng số tiền bán hàng. (Có thể là số nguyên hoặc số thập phân). Hiển thị kết quả 10 mục.

# %%
from sklearn import preprocessing

df_sales_amount = df_receipt.groupby('customer_id').agg({"amount":"sum"}).reset_index()

df_sales_amount['log_sum_amount'] = np.log(df_sales_amount['amount'] + 0.5)

df_sales_amount['log_sum_amount_ss'] = preprocessing.scale(df_sales_amount['log_sum_amount']) #x-myu / sigma

df_sales_amount.query('abs(log_sum_amount_ss) > 3').head(10)
# Out:
#          customer_id    amount  log_sum_amount  log_sum_amount_ss
# 8306  ZZ000000000000  12395003       16.332804           7.967822

# %% [markdown]
# ---
# > P-078: Tính tổng số tiền bán hàng (amount) theo từng đơn vị khách hàng từ dữ liệu chi tiết hóa đơn (df_receipt) và trích xuất các giá trị ngoại lệ của tổng số tiền bán hàng. Lưu ý rằng, loại trừ các khách hàng có ID bắt đầu bằng 'Z' vì họ là thành viên không hợp lệ. Ngoại lệ được xác định bằng cách sử dụng IQR (khoảng tứ phân vị) và được coi là giá trị dưới "Q1 - 1.5 * IQR" hoặc vượt quá "Q3 + 1.5 * IQR". Hiển thị kết quả 10 mục.

# %%
df_sales_amount = (
    df_receipt.query("not customer_id.str.startswith('Z')")
    .groupby("customer_id")
    .agg({"amount":"sum"})
    .reset_index()
)

pct25 = np.percentile(df_sales_amount['amount'], q=25) #Q1 
pct75 = np.percentile(df_sales_amount['amount'], q=75) #Q3 

iqr = pct75 - pct25
upper_threshold = pct75 + (1.5 * iqr)
lower_threshold = pct25 - (1.5 * iqr)

df_sales_amount.query('amount < @lower_threshold or amount > @upper_threshold').head(10)
# Out:
#          customer_id  amount
# 98    CS001414000048    8584
# 332   CS001605000009   18925
# 549   CS002415000594    9568
# 1180  CS004414000181    9584
# 1558  CS005415000137    8734
# 1733  CS006414000001    9156
# 1736  CS006414000029    9179
# 1752  CS006415000105   10042
# 1755  CS006415000147   12723
# 1757  CS006415000157   10648

# %% [markdown]
# ---
# > P-079:
# Kiểm tra dữ liệu sản phẩm (df_product) và phát hiện các giá trị bị thiếu.

# %%
df_product.isnull().sum()
# Out:
# product_cd            0
# category_major_cd     0
# category_medium_cd    0
# category_small_cd     0
# unit_price            7
# unit_cost             7
# dtype: int64

# %% [markdown]
# ---
# > P-080: Tạo dữ liệu sản phẩm mới bằng cách xóa tất cả các bản ghi có thiếu sót trong bất kỳ mục nào từ dữ liệu sản phẩm (df_product). Hiển thị số lượng trước và sau khi xóa, và xác nhận rằng số lượng đã giảm đúng như đã kiểm tra ở P-079.

# %%
df_product_new = df_product.copy()

df_product_new.dropna(inplace=True)

print(f"Before droppna: {len(df_product)}")
print(f"After droppna: {len(df_product_new)}")
# Out:
# Before droppna: 10030
# After droppna: 10023

# %% [markdown]
# ### Phần 5: 81 - 100

# %% [markdown]
# ---
# > P-081: Tạo dữ liệu sản phẩm mới bằng cách điền giá trị trung bình cho các mục đơn giá (unit_price) và giá vốn (unit_cost) bị thiếu. Lưu ý rằng, giá trị trung bình sẽ được làm tròn đến đơn vị yên gần nhất (có thể dùng phương pháp làm tròn lên hoặc làm tròn đến số chẵn). Sau khi thực hiện việc điền giá trị, xác nhận rằng không còn thiếu sót trong các mục này.

# %%
# 1
df_product_2 = df_product.fillna(
    {
        'unit_price': np.round(np.nanmean(df_product['unit_price'])),
        'unit_cost': np.round(np.nanmean(df_product['unit_cost']))
    }
)

df_product_2.isnull().sum()
# Out:
# product_cd            0
# category_major_cd     0
# category_medium_cd    0
# category_small_cd     0
# unit_price            0
# unit_cost             0
# dtype: int64

# %%
# 2
from sklearn.impute import SimpleImputer

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean');

imp_values = imp_mean.fit_transform(df_product[['unit_price', 'unit_cost']])

df_product_2 = df_product.copy()

df_product_2[['unit_price', 'unit_cost']] = imp_values.round()

df_product_2.isnull().sum()
# Out:
# product_cd            0
# category_major_cd     0
# category_medium_cd    0
# category_small_cd     0
# unit_price            0
# unit_cost             0
# dtype: int64

# %% [markdown]
# ---
# > P-082: Tạo dữ liệu sản phẩm mới bằng cách điền giá trị trung vị cho các mục đơn giá (unit_price) và giá vốn (unit_cost) bị thiếu. Lưu ý rằng, giá trị trung vị sẽ được làm tròn đến đơn vị yên gần nhất (có thể dùng phương pháp làm tròn lên hoặc làm tròn đến số chẵn). Sau khi thực hiện việc điền giá trị, xác nhận rằng không còn thiếu sót trong các mục này.

# %%
df_product["unit_price"].mode()[0]
# Out:
# np.float64(198.0)

# %%
df_product_3 = df_product.fillna(
    {
        'unit_price': np.round(df_product['unit_price'].median()),
        'unit_cost': np.round(df_product['unit_cost'].median())
    }
)

df_product_3.isnull().sum()
# Out:
# product_cd            0
# category_major_cd     0
# category_medium_cd    0
# category_small_cd     0
# unit_price            0
# unit_cost             0
# dtype: int64

# %% [markdown]
# ---
# > P-083: Tạo dữ liệu sản phẩm mới bằng cách điền giá trị trung vị tính theo từng mã phân loại nhỏ của danh mục sản phẩm (category_small_cd) cho các mục đơn giá (unit_price) và giá vốn (unit_cost) bị thiếu. Lưu ý rằng, giá trị trung vị sẽ được làm tròn đến đơn vị yên gần nhất (có thể dùng phương pháp làm tròn lên hoặc làm tròn đến số chẵn). Sau khi thực hiện việc điền giá trị, xác nhận rằng không còn thiếu sót trong các mục này.

# %%
# 1
df_tmp = (
    df_product.groupby('category_small_cd')
    .agg (
        median_price = ('unit_price', 'median'),
        median_cost = ('unit_cost', 'median')
    )
    .reset_index()
    .merge (
        df_product,
        how = "inner",
        on = 'category_small_cd'
    )
    .assign (
        unit_price = lambda df: df[['unit_price', 'median_price']]
            .apply(lambda x: np.round(x[1] if np.isnan(x[0]) else x[0]), axis = 1),
        unit_cost = lambda df: df[['unit_cost', 'median_cost']]
            .apply(lambda x: np.round(x[1] if np.isnan(x[0]) else x[0]), axis = 1)
    )
)
# df_tmp.head(10)

df_tmp.isnull().sum()
# Out:
# category_small_cd     0
# median_price          0
# median_cost           0
# product_cd            0
# category_major_cd     0
# category_medium_cd    0
# unit_price            0
# unit_cost             0
# dtype: int64

# %%
# 2
df_tmp = (
    df_product.groupby('category_small_cd')
    .agg (
        median_price = ('unit_price', 'median'),
        median_cost = ('unit_cost', 'median')
    )
    .reset_index()
)

df_product_2 = pd.merge (df_product, df_tmp, how='inner', on='category_small_cd')

df_product_2['unit_price'] = df_product_2[['unit_price', 'median_price']]\
            .apply(lambda x: np.round(x[1] if np.isnan(x[0]) else x[0]), axis = 1)
df_product_2['unit_cost'] = df_product_2[['unit_cost', 'median_cost']]\
            .apply(lambda x: np.round(x[1] if np.isnan(x[0]) else x[0]), axis = 1)

df_product_2.isnull().sum()
# Out:
# product_cd            0
# category_major_cd     0
# category_medium_cd    0
# category_small_cd     0
# unit_price            0
# unit_cost             0
# median_price          0
# median_cost           0
# dtype: int64

# %% [markdown]
# ---
# > P-084: Tính tỷ lệ doanh thu năm 2019 so với tổng doanh thu của toàn bộ khách hàng (df_customer) trong toàn bộ thời gian, và tạo dữ liệu mới. Trong trường hợp không có doanh thu, hãy coi như bằng 0. Sau đó, trích xuất những mục có tỷ lệ lớn hơn 0 và hiển thị kết quả 10 mục. Đồng thời, xác nhận rằng dữ liệu được tạo không có thiếu sót.

# %%
# 1
df_receipt_2019 = (
    df_receipt.query("(sales_ymd >= 20190101 & sales_ymd <= 20193131)")
    .groupby('customer_id')
    .agg (
        amount_2019 = ('amount', 'sum')
    )
    .reset_index()
)

df_receipt_all = (
    df_receipt.groupby('customer_id')
    .agg (
        amount_all = ('amount', 'sum')
    )
    .reset_index()
)

df_sales_rate = (
    df_customer[['customer_id']]
    .merge(df_receipt_2019, how = 'left', on='customer_id')
    .merge(df_receipt_all, how = 'left', on='customer_id')
    .assign (
        amount_2019 = lambda df: df['amount_2019'].fillna(0),
        amount_all = lambda df: df['amount_all'].fillna(0),
        amount_rate = lambda df: df[['amount_2019', 'amount_all']]\
                                .apply(lambda x: 0 if x[0] == 0 else x[0] / x[1], axis=1)
    )
    .query("amount_rate > 0")
)


df_sales_rate.head(10)
# Out:
#        customer_id  amount_2019  amount_all  amount_rate
# 0   CS019415000154       1862.0      5753.0     0.323657
# 1   CS008514000047        596.0       889.0     0.670416
# 4   CS033515000071       1683.0      4540.0     0.370705
# 8   CS020412000046        208.0       208.0     1.000000
# 15  CS044415000024        862.0       862.0     1.000000
# 16  CS024415000146       2872.0      4998.0     0.574630
# 45  CS019415000084        764.0      3881.0     0.196856
# 46  CS026513000087        459.0      1201.0     0.382182
# 53  CS019214000008        228.0      4481.0     0.050881
# 54  CS002515000256       1338.0      2296.0     0.582753

# %%
# 2
df_receipt_2019 = (
    df_receipt.query("(sales_ymd >= 20190101 & sales_ymd <= 20193131)")
    .groupby('customer_id')
    .agg (
        amount_2019 = ('amount', 'sum')
    )
    .reset_index()
)

df_receipt_all = (
    df_receipt.groupby('customer_id')
    .agg (
        amount_all = ('amount', 'sum')
    )
    .reset_index()
)

df_sales_rate = df_customer[['customer_id']]\
    .merge(df_receipt_2019, how = 'left', on='customer_id')\
    .merge(df_receipt_all, how = 'left', on='customer_id')

df_sales_rate['amount_2019'] = df_sales_rate['amount_2019'].fillna(0)
df_sales_rate['amount_all'] = df_sales_rate['amount_all'].fillna(0)

df_sales_rate['amount_rate'] = df_sales_rate[['amount_2019', 'amount_all']]\
                                .apply(lambda x: 0 if x[0] == 0 else x[0] / x[1], axis=1)

df_sales_rate['amount_rate'] = df_sales_rate['amount_rate'].fillna(0)

df_sales_rate.query('amount_rate > 0').head(10)
# Out:
#        customer_id  amount_2019  amount_all  amount_rate
# 0   CS019415000154       1862.0      5753.0     0.323657
# 1   CS008514000047        596.0       889.0     0.670416
# 4   CS033515000071       1683.0      4540.0     0.370705
# 8   CS020412000046        208.0       208.0     1.000000
# 15  CS044415000024        862.0       862.0     1.000000
# 16  CS024415000146       2872.0      4998.0     0.574630
# 45  CS019415000084        764.0      3881.0     0.196856
# 46  CS026513000087        459.0      1201.0     0.382182
# 53  CS019214000008        228.0      4481.0     0.050881
# 54  CS002515000256       1338.0      2296.0     0.582753

# %% [markdown]
# ---
# > P-085: Đối với toàn bộ khách hàng trong dữ liệu khách hàng (df_customer), sử dụng mã bưu điện (postal_cd) để liên kết với dữ liệu mã địa lý (df_geocode) và tạo dữ liệu khách hàng mới. Lưu ý rằng, nếu một mã bưu điện (postal_cd) có nhiều thông tin kinh độ (longitude) và vĩ độ (latitude) thì tính giá trị trung bình của kinh độ và vĩ độ để sử dụng. Hiển thị 10 mục để xác nhận kết quả đã tạo.

# %%
# 1
df_tmp = (
    df_geocode.groupby('postal_cd')
    .agg (
        m_longitude = ('longitude', 'mean'),
        m_latitude = ('latitude', 'mean')
    )
    .reset_index()
    .merge(
        df_customer, how='inner', on='postal_cd'
    )
)
df_tmp.head(10)
# Out:
#   postal_cd  m_longitude  m_latitude     customer_id    customer_name  \
# 0  167-0022    139.62378    35.72037  CS005713000021       Ruria Noda
# 1  167-0022    139.62378    35.72037  CS004513000232  Reiko Fujishima
# 2  167-0022    139.62378    35.72037  CS005415000202    Nana Ishiguro
# 3  167-0022    139.62378    35.72037  CS004215000052     Yumiko Senoo
# 4  167-0022    139.62378    35.72037  CS005415000361  Miyuki Kawahara
# 5  167-0022    139.62378    35.72037  CS005415000557      Natsumi Uno
# 6  167-0022    139.62378    35.72037  CS004215000095        Yoko Arai
# 7  167-0022    139.62378    35.72037  CS005415000563     Hikaru Ishii
# 8  167-0022    139.62378    35.72037  CS005415000025             Rary
# 9  167-0022    139.62378    35.72037  CS004412000362        Yu Tamura
#
#   gender_cd   gender   birth_day  age                         address  \
# 0         1     Male  1943-10-03   75  Suginami -ku, Tokyo Shimoigusa
# 1         1     Male  1966-09-08   52  Suginami -ku, Tokyo Shimoigusa
# 2         1     Male  1975-02-06   44  Suginami -ku, Tokyo Shimoigusa
# 3         1     Male  1989-02-02   30  Suginami -ku, Tokyo Shimoigusa
# 4         1     Male  1972-10-28   46  Suginami -ku, Tokyo Shimoigusa
# 5         1     Male  1972-11-17   46  Suginami -ku, Tokyo Shimoigusa
# 6         9  Unknown  1989-05-22   29  Suginami -ku, Tokyo Shimoigusa
# 7         1     Male  1972-05-29   46  Suginami -ku, Tokyo Shimoigusa
# 8         9  Unknown  1969-08-22   49  Suginami -ku, Tokyo Shimoigusa
# 9         1     Male  1973-07-06   45  Suginami -ku, Tokyo Shimoigusa
#
#   application_store_cd  application_date     status_cd
# 0               S13005          20150317  0-00000000-0
# 1               S13004          20161226  0-00000000-0
# 2               S13005          20150912  8-20100616-B
# 3               S13004          20150504  C-20090421-B
# 4               S13005          20170502  6-20100824-9
# 5               S13005          20170619  8-20100615-1
# 6               S13004          20160907  0-00000000-0
# 7               S13005          20170930  0-00000000-0
# 8               S13005          20150110  D-20100716-D
# 9               S13004          20161020  0-00000000-0

# %%
# 2
df_geocode_1 = df_geocode.groupby('postal_cd').agg (\
        m_longitude = ('longitude', 'mean'),\
        m_latitude = ('latitude', 'mean')
    ).reset_index()

df_customer_1 = pd.merge(df_customer, df_geocode_1, how='inner', on='postal_cd')

df_customer_1.head(10)
# Out:
#       customer_id      customer_name gender_cd gender   birth_day  age  \
# 0  CS005713000021         Ruria Noda         1   Male  1943-10-03   75
# 1  CS004513000232    Reiko Fujishima         1   Male  1966-09-08   52
# 2  CS003412000454  Okayama Natsuzora         1   Male  1971-04-30   47
# 3  CS005415000202      Nana Ishiguro         1   Male  1975-02-06   44
# 4  CS039612000088           Riho Ono         1   Male  1957-03-04   62
# 5  CS004215000052       Yumiko Senoo         1   Male  1989-02-02   30
# 6  CS019215000029        Mayuko Sawa         1   Male  1994-10-14   24
# 7  CS005415000361    Miyuki Kawahara         1   Male  1972-10-28   46
# 8  CS003412000488       Saki Okamoto         1   Male  1971-10-29   47
# 9  CS005415000557        Natsumi Uno         1   Male  1972-11-17   46
#
#   postal_cd                                          address  \
# 0  167-0022                   Suginami -ku, Tokyo Shimoigusa
# 1  167-0022                   Suginami -ku, Tokyo Shimoigusa
# 2  182-0012  Chofu -shi, Tokyo, Jindaiji Temple Higashi -cho
# 3  167-0022                   Suginami -ku, Tokyo Shimoigusa
# 4  168-0065                  Hamadayama, Suginami -ku, Tokyo
# 5  167-0022                   Suginami -ku, Tokyo Shimoigusa
# 6  176-0002                     Sakuradai, Nerima -ku, Tokyo
# 7  167-0022                   Suginami -ku, Tokyo Shimoigusa
# 8  182-0012  Chofu -shi, Tokyo, Jindaiji Temple Higashi -cho
# 9  167-0022                   Suginami -ku, Tokyo Shimoigusa
#
#   application_store_cd  application_date     status_cd  m_longitude  \
# 0               S13005          20150317  0-00000000-0    139.62378
# 1               S13004          20161226  0-00000000-0    139.62378
# 2               S13003          20171011  0-00000000-0    139.55756
# 3               S13005          20150912  8-20100616-B    139.62378
# 4               S13039          20150319  0-00000000-0    139.63101
# 5               S13004          20150504  C-20090421-B    139.62378
# 6               S13019          20151203  A-20100622-9    139.66452
# 7               S13005          20170502  6-20100824-9    139.62378
# 8               S13003          20161201  0-00000000-0    139.55756
# 9               S13005          20170619  8-20100615-1    139.62378
#
#    m_latitude
# 0    35.72037
# 1    35.72037
# 2    35.67020
# 3    35.72037
# 4    35.67802
# 5    35.72037
# 6    35.74001
# 7    35.72037
# 8    35.67020
# 9    35.72037

# %% [markdown]
# ---
# > P-086: Đối với dữ liệu khách hàng có tọa độ kinh độ vĩ độ được tạo tại 085, kết hợp với dữ liệu cửa hàng (df_store) bằng mã cửa hàng đăng ký thành viên (application_store_cd). Sau đó, sử dụng thông tin vĩ độ (latitude) và kinh độ (longitude) của cửa hàng đăng ký và địa chỉ của khách hàng (address) để tính khoảng cách (đơn vị: km) giữa cửa hàng đăng ký và địa chỉ của khách hàng, và hiển thị cả ID khách hàng (customer_id), địa chỉ khách hàng (address), và địa chỉ cửa hàng (address). Phương thức tính toán có thể đơn giản, nhưng cũng có thể sử dụng thư viện với phương thức có độ chính xác cao hơn. Hiển thị kết quả 10 mục.
# >
# > * Công thức tính khoảng cách:
#     ```
#     Vĩ độ - latitude (radian): φ
#     Kinh độ - longitude (radian): λ
#     Khoảng cách L = 6371 * arccos(sin φ₁ * sin φ₂ + cos φ₁ * cos φ₂ * cos(λ₁ - λ₂))

# %%
df_store
# df_geocode
# Out:
#    store_cd                 store_name prefecture_cd           prefecture  \
# 0    S12014           Chigakadai store            12     Chiba prefecture
# 1    S13002           Kokubunji Temple            13                Tokyo
# 2    S14010               Kikuna store            14  Kanagawa Prefecture
# 3    S14033                Akuwa store            14  Kanagawa Prefecture
# 4    S14036   Sagamihara Central Store            14  Kanagawa Prefecture
# 5    S13051       Itabashi Ohara store            13                Tokyo
# 6    S13015        Southern sand store            13                Tokyo
# 7    S14040            Nagatsuta store            14  Kanagawa Prefecture
# 8    S13044       Minami -Rokugo store            13                Tokyo
# 9    S14050          Akuwa Nishi store            14  Kanagawa Prefecture
# 10   S13019             Komorone store            13                Tokyo
# 11   S13052               Morino store            13                Tokyo
# 12   S14028       Futatsu Bridge store            14  Kanagawa Prefecture
# 13   S13031             Hatsudai store            13                Tokyo
# 14   S13038         Higashikasai store            13                Tokyo
# 15   S13001         Naka -Rokugo store            13                Tokyo
# 16   S14012         Honmaki Wada store            14  Kanagawa Prefecture
# 17   S13004             Sagimiya store            13                Tokyo
# 18   S14046           Kitayamada store            14  Kanagawa Prefecture
# 19   S14022                Zushi store            14  Kanagawa Prefecture
# 20   S14011     Hiyoshi Honmachi store            14  Kanagawa Prefecture
# 21   S13016              Koganei store            13                Tokyo
# 22   S14034      Kawasaki Nogawa store            14  Kanagawa Prefecture
# 23   S13008                Seijo store            13                Tokyo
# 24   S13020        Jujo Nakahara store            13                Tokyo
# 25   S13043    Minami -Shinagawa store            13                Tokyo
# 26   S14048        Nakagawa Chuo store            14  Kanagawa Prefecture
# 27   S12007               Sakura store            12     Chiba prefecture
# 28   S14026   Tsujido west coast store            14  Kanagawa Prefecture
# 29   S13041             Hachioji store            13                Tokyo
# 30   S13017        Koenji Minami store            13                Tokyo
# 31   S14049      Kawasaki Daishi store            14  Kanagawa Prefecture
# 32   S14023             Kawasaki store            14  Kanagawa Prefecture
# 33   S13018               Kiyose store            13                Tokyo
# 34   S13035        Yoga 4 -chome store            13                Tokyo
# 35   S14027     Minami -Fujizawa store            14  Kanagawa Prefecture
# 36   S14021              Isehara store            14  Kanagawa Prefecture
# 37   S14047           Sagamihara store            14  Kanagawa Prefecture
# 38   S12013            Narashino store            12     Chiba prefecture
# 39   S13032         Naka -Rokugo store            13                Tokyo
# 40   S14042       Niiyama Shinto store            14  Kanagawa Prefecture
# 41   S13039        Minamiogikubo store            13                Tokyo
# 42   S12030               Yawata store            12     Chiba prefecture
# 43   S13009                 Yoga store            13                Tokyo
# 44   S14025               Yamato store            14  Kanagawa Prefecture
# 45   S14045               Atsugi store            14  Kanagawa Prefecture
# 46   S13005            Shirasagi store            13                Tokyo
# 47   S12029            Higashino store            12     Chiba prefecture
# 48   S13003                Komae store            13                Tokyo
# 49   S12053               Takasu store            12     Chiba prefecture
# 50   S13037  Minamisuna 1 -chome store            13                Tokyo
# 51   S14024                 Mita store            14  Kanagawa Prefecture
# 52   S14006             Kuzugaya store            14  Kanagawa Prefecture
#
#                                               address        tel_no  \
# 0     1-chome, Chigusadai, Inage-ku, Chiba-shi, Chiba  043-123-4003
# 1                Honda 2-chome, Kokubunji City, Tokyo  042-123-4008
# 2   Kikuna 1-chome, Kohoku-ku, Yokohama-shi, Kanagawa  045-123-4032
# 3   Akuwa Nishi 1-chome, Seya-ku, Yokohama-shi, Ka...  045-123-4043
# 4   2-chome, Chuo, Sagamihara City, Kanagawa Prefe...  042-123-4045
# 5                       Ohara-cho, Itabashi-ku, Tokyo  03-0123-4029
# 6                     2-chome, Koto-ku, Tokyo 2-chome  03-0123-4014
# 7   Nagatsuda Minamidai 5-chome, Midori-ku, Yokoha...  045-123-4046
# 8                Minami Rokugo 2-chome, Ota-ku, Tokyo  03-0123-4028
# 9   Akuwa Nishi 1-chome, Seya-ku, Yokohama-shi, Ka...  045-123-4053
# 10               Komorine 1-chome, Itabashi-ku, Tokyo  03-0123-4018
# 11               Morino Sanchome, Machida City, Tokyo  042-123-4030
# 12  Futatsuhashi-cho, Seya-ku, Yokohama-shi, Kanagawa  045-123-4042
# 13                Hatsudai 2-chome, Shibuya-ku, Tokyo  03-0123-4020
# 14             Tokyo Kasai 9-chome, Edogawa-ku, Tokyo  03-0123-4024
# 15                 2-chome, Nakarokugo, Ota-ku, Tokyo  03-1234-4007
# 16      Honmaki Wada, Naka-ku, Yokohama-shi, Kanagawa  045-123-4034
# 17              Saginomiya Sanchome, Nakano-ku, Tokyo  03-0123-4010
# 18  Kitamada 1-chome, Tsuzuki-ku, Yokohama-shi, Ka...  045-123-4049
# 19     Zushi 1-chome, Zushi City, Kanagawa Prefecture  046-123-4036
# 20  4-chome Honcho, Kohoku-ku, Yokohama-shi, Kanagawa  045-123-4033
# 21               1-chome Honmachi, Koganei-shi, Tokyo  042-123-4015
# 22  Nogawa, Miyamae-ku, Kawasaki City, Kanagawa Pr...  044-123-4044
# 23                  Seijo 3-chome, Setagaya-ku, Tokyo  03-0123-4012
# 24             Jujo Nakahara Sanchome, Kita-ku, Tokyo  03-0123-4019
# 25     Minami-Shinagawa Sanchome, Shinagawa-ku, Tokyo  03-0123-4027
# 26  2-chome Nakagawa Chuo 2-chome, Tsuzuki-ku, Yok...  045-123-4051
# 27           Kamishizu, Sakura City, Chiba Prefecture  043-123-4001
# 28  2-chome, Tsujido, Fujisawa City, Kanagawa Pref...  046-123-4040
# 29                            Otsuka, Hachioji, Tokyo  042-123-4026
# 30          Koenji Minami 4-chome, Suginami-ku, Tokyo  03-0123-4016
# 31  Nakase Sanchome, Kawasaki-ku, Kawasaki City, K...  044-123-4052
# 32  2-chome Honmachi, Kawasaki-ku, Kawasaki-shi, K...  044-123-4037
# 33              Matsuyama 1-chome, Kiyose City, Tokyo  042-123-4017
# 34                   Yoga 4-chome, Setagaya-ku, Tokyo  03-0123-4022
# 35  Minami Fujisawa, Fujisawa City, Kanagawa Prefe...  046-123-4041
# 36  Isehara 4-chome, Isehara City, Kanagawa Prefec...  046-123-4035
# 37  6-chome, Chiyoda, Sagamihara City, Kanagawa Pr...  042-123-4050
# 38  1-chome Shibaen, Narashino City, Chiba Prefecture  047-123-4002
# 39                 Nakarokugo Sanchome, Ota-ku, Tokyo  03-0123-4021
# 40  Shinyamashita 2-chome, Naka-ku, Yokohama-shi, ...  045-123-4047
# 41          Minamiogikubo 4-chome, Suginami-ku, Tokyo  03-0123-4025
# 42    Yawata 3-chome, Ichikawa City, Chiba Prefecture  047-123-4005
# 43                    Setagaya-ku, Tokyo Kaga 2-chome  03-0123-4013
# 44         Shimwada, Yamato City, Kanagawa Prefecture  046-123-4039
# 45  2-chome Nakamachi, Atsugi City, Kanagawa Prefe...  046-123-4048
# 46               Shirasagi Sanchome, Nakano-ku, Tokyo  03-0123-4011
# 47  1-chome Higashino, Urayasu City, Chiba Prefecture  047-123-4004
# 48             Komae City, Tokyo Izumi Honcho 4-chome  03-0123-4009
# 49     Takasu 5-chome, Urayasu City, Chiba Prefecture  047-123-4006
# 50                  Koto-ku, Tokyo Minamisuna 1-chome  03-0123-4023
# 51  Mita 4-chome, Tama-ku, Kawasaki City, Kanagawa...  044-123-4038
# 52  Kuzugaya, Tsuzuki-ku, Yokohama City, Kanagawa ...  045-123-4031
#
#     longitude  latitude  floor_area
# 0    140.1180  35.63559      1698.0
# 1    139.4802  35.70566      1735.0
# 2    139.6326  35.50049      1732.0
# 3    139.4961  35.45918      1495.0
# 4    139.3716  35.57327      1679.0
# 5    139.6980  35.76788      1045.0
# 6    139.8229  35.67066      1337.0
# 7    139.4994  35.52398      1548.0
# 8    139.7207  35.54604      1379.0
# 9    139.4961  35.45918      1830.0
# 10   139.6795  35.74468      1004.0
# 11   139.4383  35.55293      1087.0
# 12   139.4963  35.46304      1574.0
# 13   139.6862  35.67616       986.0
# 14   139.8826  35.65366      1184.0
# 15   139.7132  35.55135      1796.0
# 16   139.6582  35.42156      1341.0
# 17   139.6421  35.72348       947.0
# 18   139.5916  35.56189       831.0
# 19   139.5789  35.29642      1838.0
# 20   139.6316  35.54655       890.0
# 21   139.5094  35.70018      1399.0
# 22   139.5998  35.57693      1318.0
# 23   139.5966  35.63614       883.0
# 24   139.7186  35.76686       801.0
# 25   139.7436  35.60981       845.0
# 26   139.5758  35.54912      1657.0
# 27   140.1452  35.71872      1895.0
# 28   139.4466  35.32464      1732.0
# 29   139.4235  35.63787       810.0
# 30   139.6513  35.70273       841.0
# 31   139.7327  35.53759       962.0
# 32   139.7028  35.53599      1804.0
# 33   139.5178  35.76885      1220.0
# 34   139.6318  35.63029       988.0
# 35   139.4896  35.33762      1521.0
# 36   139.3129  35.40169       962.0
# 37   139.3748  35.55959      1047.0
# 38   140.0220  35.66122       808.0
# 39   139.7123  35.54682      1354.0
# 40   139.6593  35.43894      1044.0
# 41   139.6152  35.70045      1133.0
# 42   139.9240  35.72318      1162.0
# 43   139.6382  35.62720      1243.0
# 44   139.4680  35.43414      1011.0
# 45   139.3651  35.44182       980.0
# 46   139.6307  35.72246      1259.0
# 47   139.8968  35.65086      1101.0
# 48   139.5668  35.64462      1529.0
# 49   139.9176  35.63755      1555.0
# 50   139.8215  35.67898       814.0
# 51   139.5424  35.60770       972.0
# 52   139.5633  35.53573      1886.0

# %%
# 1
# Hint: Cho trước công thức tính khoảng cách
def calc_distance(x1, y1, x2, y2):
    """Calculate Haversine distance 
    """
    distance = 6371 * math.acos(
        math.sin(math.radians(x1)) 
        * math.sin(math.radians(x2)) 
        + math.cos(math.radians(x1)) 
        * math.cos(math.radians(x2)) 
        * math.cos(math.radians(y1) - math.radians(y2))
    )
    return distance

df_geocode_1 = df_geocode.groupby('postal_cd').agg (\
        m_longitude = ('longitude', 'mean'),\
        m_latitude = ('latitude', 'mean')
    ).reset_index()

df_customer_1 = pd.merge(df_customer, df_geocode_1, how='inner', on='postal_cd')

df_tmp = (
    df_customer_1
    .merge(
        df_store, how='left', left_on='application_store_cd', right_on='store_cd'
    )
    .rename (
        columns = {
            'address_x':  'customer_address',
            'address_y':  'store_address'
        }
    )
    .assign (
        distance=lambda df:df[['m_latitude', 'm_longitude', 'latitude', 'longitude']]\
                    .apply(lambda x: calc_distance(x[0], x[1], x[2], x[3]), axis=1)
    )
)
df_tmp[['customer_id', 'customer_address', 'store_address', 'distance']].head(10)
# Out:
#       customer_id                                 customer_address  \
# 0  CS005713000021                   Suginami -ku, Tokyo Shimoigusa
# 1  CS004513000232                   Suginami -ku, Tokyo Shimoigusa
# 2  CS003412000454  Chofu -shi, Tokyo, Jindaiji Temple Higashi -cho
# 3  CS005415000202                   Suginami -ku, Tokyo Shimoigusa
# 4  CS039612000088                  Hamadayama, Suginami -ku, Tokyo
# 5  CS004215000052                   Suginami -ku, Tokyo Shimoigusa
# 6  CS019215000029                     Sakuradai, Nerima -ku, Tokyo
# 7  CS005415000361                   Suginami -ku, Tokyo Shimoigusa
# 8  CS003412000488  Chofu -shi, Tokyo, Jindaiji Temple Higashi -cho
# 9  CS005415000557                   Suginami -ku, Tokyo Shimoigusa
#
#                                store_address  distance
# 0       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532
# 1      Saginomiya Sanchome, Nakano-ku, Tokyo  1.689601
# 2     Komae City, Tokyo Izumi Honcho 4-chome  2.964344
# 3       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532
# 4  Minamiogikubo 4-chome, Suginami-ku, Tokyo  2.873890
# 5      Saginomiya Sanchome, Nakano-ku, Tokyo  1.689601
# 6       Komorine 1-chome, Itabashi-ku, Tokyo  1.448265
# 7       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532
# 8     Komae City, Tokyo Izumi Honcho 4-chome  2.964344
# 9       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532

# %%
# 2
from sklearn.metrics.pairwise import haversine_distances

def calc_haversine_distance(lat1, lon1, lat2, lon2):
    # Using sklearn haversine_distances to write a function to calculate distance
    # your code is here
    # ----
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    point1 = np.array([lat1, lon1]).reshape(1, -1)
    point2 = np.array([lat2, lon2]).reshape(1, -1)

    distance = haversine_distances(point1, point2)
    
    return distance[0][0] * 6371

df_tmp = (
    df_customer_1
    .merge(
        df_store, how="left", left_on="application_store_cd", right_on="store_cd"
    )
    .rename(
        columns={"address_x": "customer_address",
                 "address_y": "store_address"}
    )
    .assign(
        distance=lambda df: df[["m_latitude", "m_longitude", "latitude", "longitude"]]
                .apply(lambda x: calc_haversine_distance(x[0], x[1], x[2], x[3]), axis=1)
    )
)

df_tmp[["customer_id", "customer_address", "store_address", "distance"]].head(10)
# Out:
#       customer_id                                 customer_address  \
# 0  CS005713000021                   Suginami -ku, Tokyo Shimoigusa
# 1  CS004513000232                   Suginami -ku, Tokyo Shimoigusa
# 2  CS003412000454  Chofu -shi, Tokyo, Jindaiji Temple Higashi -cho
# 3  CS005415000202                   Suginami -ku, Tokyo Shimoigusa
# 4  CS039612000088                  Hamadayama, Suginami -ku, Tokyo
# 5  CS004215000052                   Suginami -ku, Tokyo Shimoigusa
# 6  CS019215000029                     Sakuradai, Nerima -ku, Tokyo
# 7  CS005415000361                   Suginami -ku, Tokyo Shimoigusa
# 8  CS003412000488  Chofu -shi, Tokyo, Jindaiji Temple Higashi -cho
# 9  CS005415000557                   Suginami -ku, Tokyo Shimoigusa
#
#                                store_address  distance
# 0       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532
# 1      Saginomiya Sanchome, Nakano-ku, Tokyo  1.689601
# 2     Komae City, Tokyo Izumi Honcho 4-chome  2.964344
# 3       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532
# 4  Minamiogikubo 4-chome, Suginami-ku, Tokyo  2.873890
# 5      Saginomiya Sanchome, Nakano-ku, Tokyo  1.689601
# 6       Komorine 1-chome, Itabashi-ku, Tokyo  1.448265
# 7       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532
# 8     Komae City, Tokyo Izumi Honcho 4-chome  2.964344
# 9       Shirasagi Sanchome, Nakano-ku, Tokyo  0.666532

# %% [markdown]
# ---
# > P-087: Trong dữ liệu khách hàng (df_customer), có những khách hàng được đăng ký nhiều lần do đăng ký tại các cửa hàng khác nhau. Tạo dữ liệu khách hàng đã hợp nhất (name_merge_customer_data) sao cho mỗi khách hàng chỉ có một bản ghi, dựa trên tên (customer_name) và mã bưu điện (postal_cd). Tính toán số lượng bản ghi trong dữ liệu khách hàng, số lượng bản ghi trong dữ liệu khách hàng đã hợp nhất, và số lượng bản ghi trùng lặp. Lưu ý rằng, đối với cùng một khách hàng, giữ lại bản ghi có tổng doanh thu cao nhất, và nếu tổng doanh thu bằng nhau hoặc không có doanh thu, giữ lại bản ghi có số ID khách hàng (customer_id) nhỏ hơn.

# %%
df_receipt_sumary = df_receipt.groupby('customer_id').agg(sum_amount = ('amount', 'sum')).reset_index()
df_customer_merged = pd.merge(df_customer, df_receipt_sumary, how='left', on='customer_id')

df_customer_merged['sum_amount'] = df_customer_merged['sum_amount'].fillna(0)

df_customer_merged = df_customer_merged.sort_values(
    ['sum_amount', 'customer_id'], ascending=[False, True]
)

df_customer_merged.drop_duplicates(
    subset=['customer_name', 'postal_cd'],
    keep='first',
    inplace = True
)
print (f'df_customer_cnt: {len(df_customer)}')
print (f'df_customer_merged_cnt: {len(df_customer_merged)}')
print (f'diff: {len(df_customer) - len(df_customer_merged)}')
# Out:
# df_customer_cnt: 1099
# df_customer_merged_cnt: 1099
# diff: 0

# %%
df_customer_merged.head(5)
# Out:
#         customer_id   customer_name gender_cd gender   birth_day  age  \
# 70   CS030415000034    Tamaki Nanko         1   Male  1969-01-28   50
# 583  CS020415000261  Natsumi Takada         1   Male  1970-08-03   48
# 912  CS014415000077   Mayuko Matsui         1   Male  1976-02-01   43
# 425  CS011415000193      Reina Aida         1   Male  1973-09-03   45
# 946  CS010415000121      Mika Ogawa         1   Male  1976-06-26   42
#
#     postal_cd                                            address  \
# 70   272-0025             Owada, Ichikawa City, Chiba Prefecture
# 583  114-0034                          Kita -ku, Kita -ku, Tokyo
# 912  263-0025         Anagawa -cho, Inage -ku, Chiba -shi, Chiba
# 425  223-0064  Shimoda -cho, Kohoku -ku, Yokohama -shi, Kanagawa
# 946  222-0013  Nishikigaoka, Kohoku -ku, Yokohama -shi, Kanagawa
#
#     application_store_cd  application_date     status_cd  sum_amount
# 70                S12030          20150501  F-20101020-F     15468.0
# 583               S13020          20150403  F-20101014-F     14901.0
# 912               S12014          20150923  F-20100903-F     14076.0
# 425               S14011          20150422  F-20100915-D     13637.0
# 946               S14010          20151001  F-20100410-E     11761.0

# %% [markdown]
# ---
# > P-088: Dựa trên dữ liệu đã tạo ở P-087, tạo dữ liệu khách hàng với ID hợp nhất được gán như sau:
# >
# > - Đối với khách hàng không trùng lặp: gán ID khách hàng (customer_id).
# > - Đối với khách hàng trùng lặp: gán ID khách hàng của bản ghi đã được trích xuất ở câu hỏi trước.
# >
# > Xác nhận sự khác biệt giữa số lượng ID khách hàng duy nhất và số lượng ID hợp nhất duy nhất.

# %%
df_result = pd.merge(
    df_customer,
    df_customer_merged[['customer_name', 'postal_cd', 'customer_id']], # Chỉ lấy các cột cần thiết để map
    how='inner',
    on=['customer_name', 'postal_cd']
)

df_result.rename(
    columns={'customer_id_x': 'customer_id', 'customer_id_y': 'integration_id'},
    inplace=True
)
print(f'Sự khác biệt số lượng ID: {\
    len(df_result['customer_id'].unique()) - len(df_result['integration_id'].unique())
}')
# Out:
# Sự khác biệt số lượng ID: 0

# %%
del df_result

# %% [markdown]
# ---
# > P-089: Để xây dựng mô hình dự đoán, hãy chia ngẫu nhiên dữ liệu của những khách hàng có doanh thu thành dữ liệu huấn luyện và dữ liệu kiểm tra với tỷ lệ 8:2.

# %%
from sklearn.model_selection import train_test_split
df_tmp = (
    df_receipt.groupby('customer_id').agg({'amount':'sum'}).reset_index()
    .query('amount > 0')
    .merge(df_customer, how='inner', on='customer_id')
)

df_train, df_test = train_test_split(df_tmp, test_size=0.2, random_state=2024)

print(f'Train data ratio: {len(df_train) / len(df_tmp)}')
print(f'Test data ratio: {len(df_test) / len(df_tmp)}')
# Out:
# Train data ratio: 0.8
# Test data ratio: 0.2

# %% [markdown]
# ---
# > P-090: Dữ liệu chi tiết hóa đơn (df_receipt) có dữ liệu từ ngày 1 tháng 1 năm 2017 đến ngày 31 tháng 10 năm 2019. Tính tổng doanh thu (amount) hàng tháng và tạo 3 bộ dữ liệu để xây dựng mô hình chuỗi thời gian, trong đó dữ liệu huấn luyện gồm 12 tháng và dữ liệu kiểm tra gồm 6 tháng.

# %%
# 1
# Hint: Cho trước hàm split_data
def split_data(df, train_size, test_size, slide_window, start_point):
    """
    Chia dữ liệu thành hai tập: tập huấn luyện và tập kiểm tra dựa trên các thông số đầu vào.

    Tham số:
    df (DataFrame): DataFrame đầu vào chứa dữ liệu cần chia.
    train_size (int): Kích thước của tập huấn luyện (số lượng hàng/tháng).
    test_size (int): Kích thước của tập kiểm tra (số lượng hàng/tháng).
    slide_window (int): Kích thước cửa sổ trượt (số lượng hàng/tháng) để di chuyển điểm bắt đầu.
    start_point (int): Điểm bắt đầu cho cửa sổ trượt (số lần trượt cửa sổ).

    Trả về:
    tuple: Gồm hai DataFrame:
        - df_train (DataFrame): Tập huấn luyện.
        - df_test (DataFrame): Tập kiểm tra.

    Ví dụ:
    df_train, df_test = split_data(df, train_size=12, test_size=6, slide_window=6, start_point=0)
    """
    # Tính toán vị trí bắt đầu của tập huấn luyện dựa trên điểm bắt đầu và kích thước cửa sổ trượt
    train_start = start_point * slide_window
    # Tính toán vị trí bắt đầu của tập kiểm tra dựa trên kích thước của tập huấn luyện
    test_start = train_start + train_size
    # Trả về hai DataFrame: tập huấn luyện và tập kiểm tra
    return df[train_start:test_start], df[test_start:test_start + test_size]

# Your code is below
# HERE ---

df_ts_amount = (
    df_receipt[['sales_ymd', 'amount']]
    .assign(
        sales_ym = lambda df: df['sales_ymd'].astype('str').str[0:6]
    )
    .groupby('sales_ym').agg({'amount':'sum'})
    .reset_index()
)

df_train_1, df_test_1 = split_data(df_ts_amount, train_size=12,
                                  test_size=6, slide_window=6, start_point=0)
df_train_2, df_test_2 = split_data(df_ts_amount, train_size=12,
                                  test_size=6, slide_window=6, start_point=1)
df_train_3, df_test_3 = split_data(df_ts_amount, train_size=12,
                                  test_size=6, slide_window=6, start_point=2)

# %%
df_train_1
# Out:
#    sales_ym  amount
# 0    201701  902056
# 1    201702  764413
# 2    201703  962945
# 3    201704  847566
# 4    201705  884010
# 5    201706  894242
# 6    201707  959205
# 7    201708  954836
# 8    201709  902037
# 9    201710  905739
# 10   201711  932157
# 11   201712  939654

# %%
df_test_1
# Out:
#    sales_ym   amount
# 12   201801   944509
# 13   201802   864128
# 14   201803   946588
# 15   201804   937099
# 16   201805  1004438
# 17   201806  1012329

# %%
print(df_train_1.shape)
print(df_test_1.shape)
# Out:
# (12, 2)
# (6, 2)

# %%
# 2
# Sử dụng TimeSeriesSplit từ thư viện sklearn
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(gap=0, max_train_size=12, n_splits=3, test_size=6)

df_ts_amount = df_ts_amount.query("sales_ym <= '201906'")

series_list = []

for train_index, test_index in tscv.split(df_ts_amount):
    series_list.append(
        (df_ts_amount.loc[train_index], df_ts_amount.loc[test_index])
    )

print(len(df_train_1), ",",len(df_test_1))
print(len(df_train_2), ",",len(df_test_2))
print(len(df_train_3), ",",len(df_test_3))
# Out:
# 12 , 6
# 12 , 6
# 12 , 6

# %% [markdown]
# ---
# > P-091: Đối với mỗi khách hàng trong dữ liệu khách hàng (df_customer), trích xuất dữ liệu bằng phương pháp giảm mẫu (undersampling) sao cho số lượng khách hàng có doanh thu và số lượng khách hàng không có doanh thu đạt tỷ lệ 1:1.

# %%
# Sử dụng RandomUnderSampler từ thư viện imblearn
from imblearn.under_sampling import RandomUnderSampler

df_tmp = df_receipt.groupby('customer_id').agg({'amount':'sum'})
df_tmp = pd.merge(df_customer, df_tmp, on='customer_id', how='left')
df_tmp['is_buy_flag'] = np.where(df_tmp['amount'].isnull(), 0, 1)

print("Before undersampling:")
print(df_tmp['is_buy_flag'].value_counts())
print("---")

rs = RandomUnderSampler(random_state = 2024)
df_down_sampling,_ =  rs.fit_resample(df_tmp, df_tmp['is_buy_flag'])
print("After undersampling:")
print(f'0: {len(df_down_sampling.query('is_buy_flag == 0'))}')
print(f'1: {len(df_down_sampling.query('is_buy_flag == 1'))}')
# Out:
# Before undersampling:
# is_buy_flag
# 0    679
# 1    420
# Name: count, dtype: int64
# ---
# After undersampling:
# 0: 420
# 1: 420

# %% [markdown]
# ---
# > P-092: Chuẩn hóa dữ liệu về giới tính trong dữ liệu khách hàng (df_customer) theo dạng chuẩn hóa bậc ba (3NF).

# %%
pd_gender_std = df_customer[['gender_cd', 'gender']].drop_duplicates()
pd_gender_std
# Out:
#   gender_cd   gender
# 0         9  Unknown
# 1         1     Male
# 5         0   Female

# %% [markdown]
# ---
# > P-093: Trong dữ liệu sản phẩm (df_product), chỉ có các giá trị mã của từng danh mục mà không có tên danh mục. Kết hợp với dữ liệu danh mục (df_category) để tạo dữ liệu sản phẩm mới đã được phi chuẩn hóa, có chứa tên danh mục.

# %%
df_product.head()

df_category.head()
# Out:
#   category_major_cd category_major_name category_medium_cd  \
# 0                 4           Side dish                401
# 1                 4           Side dish                401
# 2                 4           Side dish                402
# 3                 4           Side dish                402
# 4                 4           Side dish                402
#
#   category_medium_name category_small_cd  category_small_name
# 0                 Rice             40101                Lunch
# 1                 Rice             40102                Sushi
# 2            Tsukudani             40201    Seafood tsukudani
# 3            Tsukudani             40202  Sea grass tsukudani
# 4            Tsukudani             40203  Vegetable tsukudani

# %%
df_product_full = (
    df_category[['category_small_cd',
                'category_major_name',
                'category_medium_name',
                'category_small_name']]
    .assign(
        category_small_cd = lambda df: df['category_small_cd'].str.zfill(6)
    )
    .merge(df_product, how='inner', on='category_small_cd')
)

df_product_full.head(10)
# Out:
#   category_small_cd category_major_name category_medium_name  \
# 0            040101           Side dish                 Rice
# 1            040101           Side dish                 Rice
# 2            040101           Side dish                 Rice
# 3            040101           Side dish                 Rice
# 4            040101           Side dish                 Rice
# 5            040101           Side dish                 Rice
# 6            040101           Side dish                 Rice
# 7            040101           Side dish                 Rice
# 8            040101           Side dish                 Rice
# 9            040101           Side dish                 Rice
#
#   category_small_name  product_cd category_major_cd category_medium_cd  \
# 0               Lunch  P040101001                04               0401
# 1               Lunch  P040101002                04               0401
# 2               Lunch  P040101003                04               0401
# 3               Lunch  P040101004                04               0401
# 4               Lunch  P040101005                04               0401
# 5               Lunch  P040101006                04               0401
# 6               Lunch  P040101007                04               0401
# 7               Lunch  P040101008                04               0401
# 8               Lunch  P040101009                04               0401
# 9               Lunch  P040101010                04               0401
#
#    unit_price  unit_cost
# 0       198.0      149.0
# 1       218.0      164.0
# 2       230.0      173.0
# 3       248.0      186.0
# 4       268.0      201.0
# 5       298.0      224.0
# 6       338.0      254.0
# 7       420.0      315.0
# 8       498.0      374.0
# 9       580.0      435.0

# %% [markdown]
# ---
#
# > P-094: Xuất dữ liệu sản phẩm có tên danh mục được tạo tại 093 dưới các đặc điểm sau vào file.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | CSV (phân tách bằng dấu phẩy) | Có | UTF-8 |
#
# * Đường dẫn đến thư mục xuất file phải là như sau:
# ```bash
# ../../data/export_from_exercises
# ```

# %%
df_product_full.to_csv('../../data/export_from_exercises/p_df_product_full_utf8_header.csv',
                      encoding="UTF-8",
                      index=False)

# %% [markdown]
# ---
# > P-095: Xuất dữ liệu sản phẩm có tên danh mục được tạo tại 093 dưới các đặc điểm sau vào file.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | CSV (phân tách bằng dấu phẩy) | Có | CP932 |
#
# * Đường dẫn đến thư mục xuất file phải là như sau:
# ```bash
# ../../data/export_from_exercises
# ```

# %%
df_product_full.to_csv('../../data/export_from_exercises/p_df_product_full_cp932_header.csv',
                      encoding="CP932",
                      index=False)

# %% [markdown]
# ---
# > P-096: Xuất dữ liệu sản phẩm có tên danh mục được tạo tại 093 dưới các đặc điểm sau vào file.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | CSV (phân tách bằng dấu phẩy) | Không | UTF-8 |
#
# * Đường dẫn đến thư mục xuất file phải là như sau:
# ```bash
# ../../data/export_from_exercises
# ```

# %%
df_product_full.to_csv('../../data/export_from_exercises/p_df_product_full_utf8_no_header.csv',
                      encoding="UTF-8",
                      index=False, header=False)

# %% [markdown]
# ---
# P-097: Đọc file dưới đây được tạo tại 094, hiển thị và kiểm tra xem 3 mục dữ liệu có được đọc chính xác hay không.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | CSV (phân tách bằng dấu phẩy) | Có | UTF-8 |

# %%
df_product_full = pd.read_csv(
    '../../data/export_from_exercises/p_df_product_full_utf8_header.csv',
    dtype = {
        'category_major_name':str,
        'category_medium_name':str,
        'category_small_name':str
    },
    encoding='UTF-8'
)

df_product_full.head(3)
# Out:
#    category_small_cd category_major_name category_medium_name  \
# 0              40101           Side dish                 Rice
# 1              40101           Side dish                 Rice
# 2              40101           Side dish                 Rice
#
#   category_small_name  product_cd  category_major_cd  category_medium_cd  \
# 0               Lunch  P040101001                  4                 401
# 1               Lunch  P040101002                  4                 401
# 2               Lunch  P040101003                  4                 401
#
#    unit_price  unit_cost
# 0       198.0      149.0
# 1       218.0      164.0
# 2       230.0      173.0

# %% [markdown]
# ---
# P-098: Đọc file dưới đây được tạo tại 096, hiển thị và kiểm tra xem 3 mục dữ liệu có được đọc chính xác hay không.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | CSV (phân tách bằng dấu phẩy) | Không | UTF-8 |

# %%
df_product_full = pd.read_csv(
    '../../data/export_from_exercises/p_df_product_full_utf8_no_header.csv',
    encoding='UTF-8',
    header=None
)

df_product_full.head(3)
# Out:
#        0          1     2      3           4  5    6      7      8
# 0  40101  Side dish  Rice  Lunch  P040101001  4  401  198.0  149.0
# 1  40101  Side dish  Rice  Lunch  P040101002  4  401  218.0  164.0
# 2  40101  Side dish  Rice  Lunch  P040101003  4  401  230.0  173.0

# %%
df_product_full = pd.read_csv(
    '../../data/export_from_exercises/p_df_product_full_utf8_no_header.csv',
    encoding='UTF-8',
    header=None
)

df_product_full.columns = ['product_cd', 'category_major_cd', 'category_medium_cd', 'category_small_cd', 'unit_price', 'unit_cost',\
                          'category_major_name', 'category_medium_name', 'category_small_name']

df_product_full.head(3)
# Out:
#    product_cd category_major_cd category_medium_cd category_small_cd  \
# 0       40101         Side dish               Rice             Lunch
# 1       40101         Side dish               Rice             Lunch
# 2       40101         Side dish               Rice             Lunch
#
#    unit_price  unit_cost  category_major_name  category_medium_name  \
# 0  P040101001          4                  401                 198.0
# 1  P040101002          4                  401                 218.0
# 2  P040101003          4                  401                 230.0
#
#    category_small_name
# 0                149.0
# 1                164.0
# 2                173.0

# %% [markdown]
# ---
# P-099: Xuất dữ liệu sản phẩm có tên danh mục được tạo tại 093 dưới các đặc điểm sau vào file.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | TSV (phân tách bằng tab) | Có | UTF-8 |
#
# * Đường dẫn đến thư mục xuất file phải là như sau:
# ```bash
# ../../data/export_from_exercises
# ```

# %%
df_product_full.to_csv('../../data/export_from_exercises/p_df_product_full_utf8_no_header.tsv',
                      encoding="UTF-8",
                      index=False, sep='\t')

# %% [markdown]
# ---
# P-100: Đọc file dưới đây được tạo tại 099, hiển thị và kiểm tra xem 3 mục dữ liệu có được đọc chính xác hay không.
#
# | Định dạng file | Có tiêu đề hay không | Mã hóa ký tự |
# |----------------|----------------------|--------------|
# | TSV (phân tách bằng tab) | Có | UTF-8 |

# %%
# 1 Sử dụng read table
df_product_full = pd.read_table("../../data/export_from_exercises/p_df_product_full_utf8_header.tsv", 
                       dtype={'category_major_cd':str,
                              'category_medium_cd':str,
                              'category_small_cd':str},
                       encoding='UTF-8')
df_product_full.head(3)
# Out:
#    product_cd category_major_cd category_medium_cd category_small_cd  \
# 0       40101         Side dish               Rice             Lunch
# 1       40101         Side dish               Rice             Lunch
# 2       40101         Side dish               Rice             Lunch
#
#    unit_price  unit_cost  category_major_name  category_medium_name  \
# 0  P040101001          4                  401                 198.0
# 1  P040101002          4                  401                 218.0
# 2  P040101003          4                  401                 230.0
#
#    category_small_name
# 0                149.0
# 1                164.0
# 2                173.0

# %%
# 2 Sử dụng pd.read_csv()
df_product_full = pd.read_csv("../../data/export_from_exercises/p_df_product_full_utf8_header.tsv", 
                       encoding='UTF-8', sep='\t')
df_product_full.head(3)
# Out:
#    product_cd category_major_cd category_medium_cd category_small_cd  \
# 0       40101         Side dish               Rice             Lunch
# 1       40101         Side dish               Rice             Lunch
# 2       40101         Side dish               Rice             Lunch
#
#    unit_price  unit_cost  category_major_name  category_medium_name  \
# 0  P040101001          4                  401                 198.0
# 1  P040101002          4                  401                 218.0
# 2  P040101003          4                  401                 230.0
#
#    category_small_name
# 0                149.0
# 1                164.0
# 2                173.0

# %% [markdown]
# ## Lời kết
# * **Chúc mừng bạn đã hoàn thành 100 bài tập về Pandas. Bây giờ bạn hoàn toàn có thể tự tin vào khả năng sử dụng pandas cho công việc phân tích dữ liệu của bạn !**
